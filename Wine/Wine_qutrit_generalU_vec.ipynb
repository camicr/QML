# %%
import os
import torch
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, cohen_kappa_score, matthews_corrcoef
import pandas as pd
import time
from sklearn import datasets
from sklearn.datasets import load_wine
from sklearn.utils import shuffle
from copy import deepcopy

# %%
'''
     ==================
       some functions
     ==================
'''

def evaluate_accuracy(dataloader, model):
    model.eval()
    y_true, y_pred = [], []

    with torch.no_grad():
        for data, target in dataloader:
            output = model(data)
            preds = torch.argmax(output, dim=1)
            y_true.extend(target.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())

    return (
        accuracy_score(y_true, y_pred, ) * 100,
        f1_score(y_true, y_pred, average='macro', zero_division=0) * 100,
        precision_score(y_true, y_pred, average='macro', zero_division=0) * 100,
        recall_score(y_true, y_pred, average='macro', zero_division=0) * 100,
        cohen_kappa_score(y_true, y_pred),
        matthews_corrcoef(y_true, y_pred),
        y_true, 
        y_pred
        )
        
def cost_fidelity(output, target):
    return torch.mean((1 - output[range(len(target)), target]) ** 2)

# %%
'''
      ==================
         1 qutrit QNN
      ==================
'''

# class QNN_0_Sum(nn.Module):

#     def __init__(self, num_layers, num_features, num_params, init_weights=None):
#         super(QNN_0_Sum, self).__init__()

#         self.num_layers = num_layers
#         self.num_features = num_features
#         self.num_params = num_params

#         # Qutrit basis
#         q0 = torch.tensor([[1], [0], [0]], dtype=torch.complex64)
#         q1 = torch.tensor([[0], [1], [0]], dtype=torch.complex64)
#         q2 = torch.tensor([[0], [0], [1]], dtype=torch.complex64)
#         self.register_buffer("q0", q0)
#         self.register_buffer("q1", q1)
#         self.register_buffer("q2", q2)

#         # Outer product helper
#         gm = lambda A, B: torch.kron(A, B.T)

#         # Gell-Mann generators
#         # Gell-Mann generators
#         gm1 = (gm(q0, q1) + gm(q1, q0)).to(torch.complex64)
#         gm2 = (-1j * (gm(q0, q1) - gm(q1, q0))).to(torch.complex64)
#         gm3 = (gm(q0, q0) - gm(q1, q1)).to(torch.complex64)
#         gm4 = (gm(q0, q2) + gm(q2, q0)).to(torch.complex64)
#         gm5 = (-1j * (gm(q0, q2) - gm(q2, q0))).to(torch.complex64)
#         gm6 = (gm(q1, q2) + gm(q2, q1)).to(torch.complex64)
#         gm7 = (-1j * (gm(q1, q2) - gm(q2, q1))).to(torch.complex64)
#         gm8 = (1 / torch.sqrt(torch.tensor(3., dtype=torch.float32)) * (gm(q0, q0) + gm(q1, q1) - 2 * gm(q2, q2))).to(torch.complex64)
            
#         Sz12 = (gm(q1, q1) - gm(q2, q2)).to(torch.complex64)
#         Sz02 = (gm(q0, q0) - gm(q2, q2)).to(torch.complex64)
        
        
#         # Configurations
        
#         #C30
#         generators12345678 = [gm1,
#                               gm2,
#                               gm3, 
#                               gm4, 
#                               gm5,
#                               gm6,
#                               gm7,
#                               gm8]
        
#         #C31
#         generators123 = [gm1,
#                          gm2, 
#                          gm3]
        
#         generators456 = [gm4,
#                          gm5, 
#                          gm6]
        
#         #C32     
#         generatorsYYY = [gm2,  # Sy_01
#                          gm5,  # Sy_02
#                          gm7]  # Sy_12
                     


#         #C32           
#         generatorsYYYZ = [gm2,  # Sy_01
#                           gm5,  # Sy_02
#                           gm7,  # Sy_12
#                           gm3]  # Sz_01
        
    
        
#         generators_enc = generatorsYYY
        
#         generators_var = generatorsYYY
            
        
#         self.register_buffer("gens_enc", torch.stack(generators_enc[:self.num_features]))  # [F, 3, 3]
#         self.register_buffer("gens_var", torch.stack(generators_var[:self.num_params]))  # [F, 3, 3]
        
#         # Label projectors
#         self.register_buffer("label_ops", torch.stack([gm(q, q) for q in [q0, q1, q2]]))


#         # Per-layer weights with num_features components
#         self.weights = nn.ParameterList([
#             nn.Parameter(init_weights[i] if init_weights else torch.rand(self.num_params) * 2 - 1)
#             for i in range(num_layers)
#         ])

#     def forward(self, batch):
#         """
#         batch: Tensor of shape [B, num_features]
#         """
#         B = batch.shape[0]

#         # Initial qutrit state expanded for batch: [B, 3, 1]
#         state = self.q0.expand(B, -1, -1).clone()  # [B, 3, 1]
        
#         one_j = torch.tensor(1j, dtype=torch.complex64)

#         for i in range(self.num_layers):
#             # Encoding
#             gen = self.gens_enc.unsqueeze(0)  # [1, F, 3, 3]
#             x = batch.unsqueeze(-1).unsqueeze(-1)  # [B, F, 1, 1]
#             encoded = (x * gen).sum(dim=1).to(torch.complex64)  # [B, 3, 3]
#             U_enc = torch.matrix_exp(one_j * encoded)
#             state = torch.matmul(U_enc, state)
            
#             # Variational
#             gen = self.gens_var.unsqueeze(0) 
#             w = self.weights[i].unsqueeze(0).expand(B, -1).unsqueeze(-1).unsqueeze(-1)
#             encoded = (w * gen).sum(dim=1).to(torch.complex64)
#             U_var = torch.matrix_exp(one_j * encoded)
#             state = torch.matmul(U_var, state)


#         # ----- Density matrix -----
#         rho = torch.matmul(state, state.conj().transpose(-2, -1))  # [B, 3, 3]
#         rho = (rho + rho.conj().transpose(-2, -1)) / 2  # Hermitian

#         # ----- Fidelities -----
#         fidelities = []
#         for op in self.label_ops:
#             op_batch = op.unsqueeze(0).expand(B, -1, -1)  # [B, 3, 3]
#             product = torch.matmul(rho, op_batch)  # [B, 3, 3]
#             eigvals, _ = torch.linalg.eig(product)
#             eigvals_real = torch.clamp(eigvals.real, min=1e-10)
#             fidelities.append(torch.sum(torch.sqrt(eigvals_real), dim=1) ** 2)

#         fstack = torch.stack(fidelities, dim=1)  # [B, 3]
#         return fstack / fstack.sum(dim=1, keepdim=True)


# General SU(N)-----------------
class QNN_0_Prod(nn.Module):
    
    def __init__(self, num_layers, num_features, num_params, init_weights=None):
        super(QNN_0_Prod, self).__init__()
        self.num_layers = num_layers
        self.num_features = num_features
        self.num_params = num_params

        # Qutrit basis
        q0 = torch.tensor([[1], [0], [0]], dtype=torch.complex64)
        q1 = torch.tensor([[0], [1], [0]], dtype=torch.complex64)
        q2 = torch.tensor([[0], [0], [1]], dtype=torch.complex64)
        self.register_buffer("q0", q0)
        self.register_buffer("q1", q1)
        self.register_buffer("q2", q2)

        # Outer product helper
        gm = lambda A, B: torch.kron(A, B.T)
        
        # Gell-Mann generators
        gm1 = (gm(q0, q1) + gm(q1, q0)).to(torch.complex64)
        gm2 = (-1j * (gm(q0, q1) - gm(q1, q0))).to(torch.complex64)
        gm3 = (gm(q0, q0) - gm(q1, q1)).to(torch.complex64)
        gm4 = (gm(q0, q2) + gm(q2, q0)).to(torch.complex64)
        gm5 = (-1j * (gm(q0, q2) - gm(q2, q0))).to(torch.complex64)
        gm6 = (gm(q1, q2) + gm(q2, q1)).to(torch.complex64)
        gm7 = (-1j * (gm(q1, q2) - gm(q2, q1))).to(torch.complex64)
        gm8 = (1 / torch.sqrt(torch.tensor(3., dtype=torch.float32)) * (gm(q0, q0) + gm(q1, q1) - 2 * gm(q2, q2))).to(torch.complex64)
            
        Sz12 = (gm(q1, q1) - gm(q2, q2)).to(torch.complex64)
        Sz02 = (gm(q0, q0) - gm(q2, q2)).to(torch.complex64)
        
        # Configurations
        
        # C32
        generatorsYYY = [gm2,    # RY_01
                         gm5,    # RY_02
                         gm7]    # RY_12
        
        generatorsZZZ = [gm3,    # RZ_01
                         Sz02,   # RZ_02
                         Sz12]   # RZ_12
        
        generatorsYYYZ = [gm2,   # RY_01
                          gm5,   # RY_02
                          gm7,   # RY_12
                          gm3]   # RZ_01
        
        generatorYZYZ = [gm2,    # RY_01
                         gm3,    # RZ_01
                         gm7,    # RY_12
                         Sz12]   # RZ_12

        generators_generalU = [gm8,
                               gm3,
                               gm2,
                               gm3,
                               gm5,
                               gm3,
                               gm2,
                               gm3]

        generators_enc = generators_generalU
        generators_var = generators_generalU
     
        # Subset para codificación, todos para la parte variacional
        self.register_buffer("gens_enc", torch.stack(generators_enc[:self.num_features]))  # [F, 3, 3]
        self.register_buffer("gens_var", torch.stack(generators_var[:self.num_params]))    # [P, 3, 3]
        
        # Label projectors: |0><0|, |1><1|, |2><2|
        self.register_buffer("label_ops", torch.stack([gm(q, q) for q in [q0, q1, q2]]))

        # initial state
        self.q0 = q0

        # parameters per layer
        self.weights = nn.ParameterList([
            nn.Parameter(init_weights[i] if init_weights else torch.rand(6)*2 - 1)
            for i in range(num_layers)
        ])

    def forward(self, batch):
        batch_size = batch.shape[0]
        batch_c = batch.to(torch.cfloat)

        state = self.q0.expand(batch_size, -1, -1).clone()

        for i in range(self.num_layers):
            # Encoding
            for j in range(self.num_features):
                G = self.gens_enc[j]
                x = batch_c[:, j].view(-1, 1, 1)
                U = torch.matrix_exp(1j * x * G)
                state = torch.bmm(U, state)

            # Variational
            for j, G in enumerate(self.gens_var):
                theta = self.weights[i][j]
                U = torch.matrix_exp(1j * theta * G)
                state = torch.matmul(U, state)

        # density matrix
        rho = state @ state.conj().transpose(-2, -1)
        rho = (rho + rho.conj().transpose(-2, -1)) / 2  # ensure Hermitian

        # fidelity
        fidelities = []
        for op in self.label_ops:
            op_batch = op.unsqueeze(0).expand(batch_size, -1, -1)
            product = rho @ op_batch
            eigvals, _ = torch.linalg.eig(product)
            eigvals_real = torch.clamp(eigvals.real, min=1e-10)
            fidelities.append(torch.sum(torch.sqrt(eigvals_real), dim=1) ** 2)

        fstack = torch.stack(fidelities, dim=1)
        return fstack / fstack.sum(dim=1, keepdim=True)

# %%
'''
      ==================
            data
      ==================
'''

# create MinMaxScaler object
scaler = MinMaxScaler()


class CustomDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]



def load_dataset(n_components):

    # dataset
    wine = load_wine()

    # features
    X_data = wine.data
    X_data = scaler.fit_transform(X_data)

    # labels
    y_data = wine.target

    pca = PCA(n_components=n_components)

    x_data = pca.fit_transform(X_data)

    x_data, y_data = shuffle(x_data, y_data, random_state=42)

    return x_data, y_data, pca.explained_variance_ratio_.sum()

# %%
'''
     =====================================
                training (prod)
     =====================================
'''

def eval_loss_full(dataloader, model):
    model.eval()
    tot = 0.0
    n = 0
    with torch.no_grad():
        for data, target in dataloader:
            out = model(data)
            l = cost_fidelity(out, target)
            bs = data.size(0)
            tot += float(l) * bs
            n += bs
    return tot / max(n, 1)

# Configs
N_TRIALS     = 2000
EPOCHS       = 200
BATCH_SIZE   = 32
LAYERS       = 6
LR           = 0.006
SAVE_EVERY   = 100
NUM_FEATURES = 4
NUM_PARAMS   = 8

BASE_SAVE_DIR = "/Users/ccristiano/Documents/Codigos/QML/Wine/qutrit/data/SequentialTraining"
os.makedirs(BASE_SAVE_DIR, exist_ok=True)


# Tracking (Option 1)
results_all = []
best_params_by_param = {}
best_loss = float("inf")
best_params = None
best_train_acc = 0.0
best_init_weights = None
best_training_time = None
best_so_far_rows = [] 
log_progress = []
chunk = 1

# Tracking (Option 2)
# import ast
# results_all = []
# best_params_by_param = {}
# metrics_file = f"{BASE_SAVE_DIR}/modelo_optimo_NUM_FEATURES_{NUM_FEATURES}_NUM_PARAMS_{NUM_PARAMS}_metrics.csv"
# df_prev = pd.read_csv(metrics_file)
# best_loss = float(df_prev["Loss"].iloc[0])
# best_train_acc = float(df_prev["TrainAcc"].iloc[0])
# best_init_weights = ast.literal_eval(df_prev["InitWeights"].iloc[0])
# best_init_weights = [torch.tensor(w, dtype=torch.float32) for w in best_init_weights]
# best_params = torch.load(f"{BASE_SAVE_DIR}/params_NUM_FEATURES_{NUM_FEATURES}_NUM_PARAMS_{NUM_PARAMS}.pt")
# print(f"📂 Cargado mejor modelo anterior: loss={best_loss:.6f}, acc={best_train_acc:.2f}%")
# best_training_time = None
# best_so_far_rows = [] 
# log_progress = []
# chunk = 1

# Dataset
X, y, exp_var = load_dataset(NUM_FEATURES)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)
train_dl = DataLoader(CustomDataset(X_train, y_train), batch_size=BATCH_SIZE, shuffle=True)
test_dl  = DataLoader(CustomDataset(X_test,  y_test),  batch_size=BATCH_SIZE, shuffle=False)
print(f"Explained variance is {exp_var}")

for trial in range(1, N_TRIALS + 1):
    print(f"\n🎯 Trial {trial}/{N_TRIALS}...")

    time_start_trial = time.time()

    # Inicialization
    init_weights = [torch.rand(NUM_PARAMS) * 2 - 1 for _ in range(LAYERS)]
    model = QNN_0_Prod(LAYERS, NUM_FEATURES, NUM_PARAMS, init_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=LR)

    # (Opcional)
    for p in model.parameters():
        p.data.clamp_(-2 * np.pi, 2 * np.pi)

    # Training
    for epoch in range(EPOCHS):
        model.train()
        for data, target in train_dl:
            optimizer.zero_grad()
            out = model(data)
            loss = cost_fidelity(out, target)   
            loss.backward()
            optimizer.step()

    # Loss over the whole dataset
    final_loss = eval_loss_full(train_dl, model)

    # Train accuracy
    train_acc, *_ = evaluate_accuracy(train_dl, model)

    # Trial training time
    time_end_trial = time.time() - time_start_trial

    # Save best trial (by loss)
    if final_loss < best_loss:
        best_loss = final_loss
        best_params = deepcopy(model.state_dict())
        best_train_acc = train_acc
        best_init_weights = deepcopy(init_weights)
        best_training_time = time_end_trial
        
    # Register
    best_so_far_rows.append({
        "Trial": trial,
        "BestLossSoFar": best_loss,
        "BestTrainAccSoFar": best_train_acc
    })

    print(f"   🔍 Final Train Loss (avg): {final_loss:.6f} | "
          f"Best so far: {best_loss:.6f} | Train Acc: {train_acc:.2f}% | "
          f"Time: {time_end_trial:.2f}s")


    # Progress log
    log_progress.append({
        "NUM_FEATURES": NUM_FEATURES,
        "Trial": trial,
        "BestTrainLoss": best_loss,
        "BestTrainAcc": best_train_acc,
        "Time": time_end_trial
    })

    # Save data 
    if trial % SAVE_EVERY == 0:
        df_log = pd.DataFrame(log_progress)
        file_name = f"{BASE_SAVE_DIR}/train_progress_NUMFEATURES_{NUM_FEATURES}_NUM_PARAMS_{NUM_PARAMS}_LAYERS_{LAYERS}_{chunk}.csv"
        df_log.to_csv(file_name, index=False)

        # Reiniciar logs del bloque
        log_progress = []
        chunk += 1

# Evaluate in test dataset
model = QNN_0_Prod(LAYERS, NUM_FEATURES, NUM_PARAMS, [w.detach().clone() for w in best_init_weights])
model.load_state_dict(best_params)
test_acc, test_f1, test_prec, test_rec, test_kappa, test_matthews, _, _ = evaluate_accuracy(test_dl, model)

# Save model and metrics
torch.save(best_params, f"{BASE_SAVE_DIR}/params_NUM_FEATURES_{NUM_FEATURES}_NUM_PARAMS_{NUM_PARAMS}_LAYERS_{LAYERS}.pt")

df_test_metrics = pd.DataFrame([{
    "NUM_FEATURES": NUM_FEATURES,
    "NUM_PARAMS": NUM_PARAMS,
    "Loss": best_loss,  
    "TrainAcc": best_train_acc,
    "TestAcc": test_acc,
    "TestF1": test_f1,
    "TestPrecision": test_prec,
    "TestRecall": test_rec,
    "CohenKappa": test_kappa,
    "MatthewsCorr": test_matthews,
    "InitWeights": [w.detach().cpu().numpy().tolist() for w in best_init_weights],
    "TrainingTime": best_training_time
}])

df_test_metrics.to_csv(
    f"{BASE_SAVE_DIR}/metrics_NUMFEATURES_{NUM_FEATURES}_NUM_PARAMS_{NUM_PARAMS}_LAYERS_{LAYERS}.csv",
    index=False
)

os.makedirs(BASE_SAVE_DIR, exist_ok=True)
pd.DataFrame(best_so_far_rows).to_csv(
    f"{BASE_SAVE_DIR}/best_so_far_NUMFEATURES_{NUM_FEATURES}_NUM_PARAMS_{NUM_PARAMS}_LAYERS_{LAYERS}.csv",
    index=False
)
# Out:
# Explained variance is 0.7570818476302278
#
# 🎯 Trial 1/2000...
#    🔍 Final Train Loss (avg): 0.060590 | Best so far: 0.060590 | Train Acc: 94.37% | Time: 10.00s
#
# 🎯 Trial 2/2000...
#    🔍 Final Train Loss (avg): 0.058468 | Best so far: 0.058468 | Train Acc: 96.48% | Time: 9.34s
#
# 🎯 Trial 3/2000...
#    🔍 Final Train Loss (avg): 0.053187 | Best so far: 0.053187 | Train Acc: 95.07% | Time: 9.48s
#
# 🎯 Trial 4/2000...
#    🔍 Final Train Loss (avg): 0.054621 | Best so far: 0.053187 | Train Acc: 93.66% | Time: 9.40s
#
# 🎯 Trial 5/2000...
#    🔍 Final Train Loss (avg): 0.046384 | Best so far: 0.046384 | Train Acc: 96.48% | Time: 9.43s
#
# 🎯 Trial 6/2000...
#    🔍 Final Train Loss (avg): 0.065093 | Best so far: 0.046384 | Train Acc: 94.37% | Time: 10.87s
#
# 🎯 Trial 7/2000...
#    🔍 Final Train Loss (avg): 0.052639 | Best so far: 0.046384 | Train Acc: 95.07% | Time: 9.58s
#
# 🎯 Trial 8/2000...
#    🔍 Final Train Loss (avg): 0.070085 | Best so far: 0.046384 | Train Acc: 92.96% | Time: 9.70s
#
# 🎯 Trial 9/2000...
#    🔍 Final Train Loss (avg): 0.046867 | Best so far: 0.046384 | Train Acc: 97.18% | Time: 9.66s
#
# 🎯 Trial 10/2000...
#    🔍 Final Train Loss (avg): 0.048191 | Best so far: 0.046384 | Train Acc: 95.77% | Time: 9.49s
#
# 🎯 Trial 11/2000...
#    🔍 Final Train Loss (avg): 0.052136 | Best so far: 0.046384 | Train Acc: 95.77% | Time: 9.51s
#
# 🎯 Trial 12/2000...
#    🔍 Final Train Loss (avg): 0.068597 | Best so far: 0.046384 | Train Acc: 95.07% | Time: 9.47s
#
# 🎯 Trial 13/2000...
#    🔍 Final Train Loss (avg): 0.058182 | Best so far: 0.046384 | Train Acc: 95.77% | Time: 9.27s
#
# 🎯 Trial 14/2000...
#    🔍 Final Train Loss (avg): 0.061319 | Best so far: 0.046384 | Train Acc: 94.37% | Time: 9.32s
#
# 🎯 Trial 15/2000...
#    🔍 Final Train Loss (avg): 0.053731 | Best so far: 0.046384 | Train Acc: 95.77% | Time: 9.39s
#
# 🎯 Trial 16/2000...
#    🔍 Final Train Loss (avg): 0.056675 | Best so far: 0.046384 | Train Acc: 96.48% | Time: 9.26s
#
# 🎯 Trial 17/2000...
#    🔍 Final Train Loss (avg): 0.049728 | Best so far: 0.046384 | Train Acc: 95.07% | Time: 9.47s
#
# 🎯 Trial 18/2000...
#    🔍 Final Train Loss (avg): 0.052401 | Best so far: 0.046384 | Train Acc: 95.07% | Time: 9.31s
#
# 🎯 Trial 19/2000...
#    🔍 Final Train Loss (avg): 0.051296 | Best so far: 0.046384 | Train Acc: 95.77% | Time: 9.31s
#
# 🎯 Trial 20/2000...
#    🔍 Final Train Loss (avg): 0.062443 | Best so far: 0.046384 | Train Acc: 93.66% | Time: 9.27s
#
# 🎯 Trial 21/2000...
#    🔍 Final Train Loss (avg): 0.047308 | Best so far: 0.046384 | Train Acc: 97.89% | Time: 9.33s
#
# 🎯 Trial 22/2000...
#    🔍 Final Train Loss (avg): 0.058721 | Best so far: 0.046384 | Train Acc: 95.07% | Time: 9.48s
#
# 🎯 Trial 23/2000...
#    🔍 Final Train Loss (avg): 0.052758 | Best so far: 0.046384 | Train Acc: 96.48% | Time: 9.29s
#
# 🎯 Trial 24/2000...
#    🔍 Final Train Loss (avg): 0.053560 | Best so far: 0.046384 | Train Acc: 95.77% | Time: 9.40s
#
# 🎯 Trial 25/2000...
#    🔍 Final Train Loss (avg): 0.050601 | Best so far: 0.046384 | Train Acc: 94.37% | Time: 9.29s
#
# 🎯 Trial 26/2000...
#    🔍 Final Train Loss (avg): 0.050101 | Best so far: 0.046384 | Train Acc: 96.48% | Time: 9.36s
#
# 🎯 Trial 27/2000...
#    🔍 Final Train Loss (avg): 0.049581 | Best so far: 0.046384 | Train Acc: 97.18% | Time: 9.30s
#
# 🎯 Trial 28/2000...
#    🔍 Final Train Loss (avg): 0.050807 | Best so far: 0.046384 | Train Acc: 97.18% | Time: 9.46s
#
# 🎯 Trial 29/2000...
#    🔍 Final Train Loss (avg): 0.056545 | Best so far: 0.046384 | Train Acc: 93.66% | Time: 9.33s
#
# 🎯 Trial 30/2000...
#    🔍 Final Train Loss (avg): 0.059853 | Best so far: 0.046384 | Train Acc: 95.77% | Time: 10.05s
#
# 🎯 Trial 31/2000...
#    🔍 Final Train Loss (avg): 0.054597 | Best so far: 0.046384 | Train Acc: 95.77% | Time: 9.31s
#
# 🎯 Trial 32/2000...
#    🔍 Final Train Loss (avg): 0.057433 | Best so far: 0.046384 | Train Acc: 93.66% | Time: 9.41s
#
# 🎯 Trial 33/2000...
#    🔍 Final Train Loss (avg): 0.050413 | Best so far: 0.046384 | Train Acc: 96.48% | Time: 9.35s
#
# 🎯 Trial 34/2000...
#    🔍 Final Train Loss (avg): 0.056027 | Best so far: 0.046384 | Train Acc: 96.48% | Time: 9.49s
#
# 🎯 Trial 35/2000...
#    🔍 Final Train Loss (avg): 0.058075 | Best so far: 0.046384 | Train Acc: 93.66% | Time: 9.30s
#
# 🎯 Trial 36/2000...
#    🔍 Final Train Loss (avg): 0.049669 | Best so far: 0.046384 | Train Acc: 95.77% | Time: 9.21s
#
# 🎯 Trial 37/2000...
#    🔍 Final Train Loss (avg): 0.055358 | Best so far: 0.046384 | Train Acc: 95.07% | Time: 9.51s
#
# 🎯 Trial 38/2000...
#    🔍 Final Train Loss (avg): 0.064221 | Best so far: 0.046384 | Train Acc: 94.37% | Time: 9.26s
#
# 🎯 Trial 39/2000...
#    🔍 Final Train Loss (avg): 0.056353 | Best so far: 0.046384 | Train Acc: 97.18% | Time: 9.40s
#
# 🎯 Trial 40/2000...
#    🔍 Final Train Loss (avg): 0.048716 | Best so far: 0.046384 | Train Acc: 96.48% | Time: 9.75s
#
# 🎯 Trial 41/2000...
#    🔍 Final Train Loss (avg): 0.056221 | Best so far: 0.046384 | Train Acc: 95.07% | Time: 9.50s
#
# 🎯 Trial 42/2000...
#    🔍 Final Train Loss (avg): 0.051761 | Best so far: 0.046384 | Train Acc: 95.77% | Time: 9.48s
#
# 🎯 Trial 43/2000...
#    🔍 Final Train Loss (avg): 0.049211 | Best so far: 0.046384 | Train Acc: 95.77% | Time: 9.59s
#
# 🎯 Trial 44/2000...
#    🔍 Final Train Loss (avg): 0.060297 | Best so far: 0.046384 | Train Acc: 92.96% | Time: 9.51s
#
# 🎯 Trial 45/2000...
#    🔍 Final Train Loss (avg): 0.056009 | Best so far: 0.046384 | Train Acc: 95.07% | Time: 9.24s
#
# 🎯 Trial 46/2000...
#    🔍 Final Train Loss (avg): 0.064278 | Best so far: 0.046384 | Train Acc: 93.66% | Time: 9.35s
#
# 🎯 Trial 47/2000...
#    🔍 Final Train Loss (avg): 0.047792 | Best so far: 0.046384 | Train Acc: 95.77% | Time: 9.28s
#
# 🎯 Trial 48/2000...
#    🔍 Final Train Loss (avg): 0.045131 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.33s
#
# 🎯 Trial 49/2000...
#    🔍 Final Train Loss (avg): 0.050607 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.32s
#
# 🎯 Trial 50/2000...
#    🔍 Final Train Loss (avg): 0.052175 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.35s
#
# 🎯 Trial 51/2000...
#    🔍 Final Train Loss (avg): 0.059312 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.37s
#
# 🎯 Trial 52/2000...
#    🔍 Final Train Loss (avg): 0.051953 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.59s
#
# 🎯 Trial 53/2000...
#    🔍 Final Train Loss (avg): 0.074948 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.40s
#
# 🎯 Trial 54/2000...
#    🔍 Final Train Loss (avg): 0.057869 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.37s
#
# 🎯 Trial 55/2000...
#    🔍 Final Train Loss (avg): 0.058850 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.51s
#
# 🎯 Trial 56/2000...
#    🔍 Final Train Loss (avg): 0.055932 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.31s
#
# 🎯 Trial 57/2000...
#    🔍 Final Train Loss (avg): 0.053624 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.35s
#
# 🎯 Trial 58/2000...
#    🔍 Final Train Loss (avg): 0.050525 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 10.07s
#
# 🎯 Trial 59/2000...
#    🔍 Final Train Loss (avg): 0.067876 | Best so far: 0.045131 | Train Acc: 91.55% | Time: 9.39s
#
# 🎯 Trial 60/2000...
#    🔍 Final Train Loss (avg): 0.055821 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.24s
#
# 🎯 Trial 61/2000...
#    🔍 Final Train Loss (avg): 0.057291 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.32s
#
# 🎯 Trial 62/2000...
#    🔍 Final Train Loss (avg): 0.056960 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.23s
#
# 🎯 Trial 63/2000...
#    🔍 Final Train Loss (avg): 0.061822 | Best so far: 0.045131 | Train Acc: 92.96% | Time: 9.27s
#
# 🎯 Trial 64/2000...
#    🔍 Final Train Loss (avg): 0.063185 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.31s
#
# 🎯 Trial 65/2000...
#    🔍 Final Train Loss (avg): 0.055432 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.47s
#
# 🎯 Trial 66/2000...
#    🔍 Final Train Loss (avg): 0.059636 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 10.47s
#
# 🎯 Trial 67/2000...
#    🔍 Final Train Loss (avg): 0.053483 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.27s
#
# 🎯 Trial 68/2000...
#    🔍 Final Train Loss (avg): 0.049850 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.27s
#
# 🎯 Trial 69/2000...
#    🔍 Final Train Loss (avg): 0.052170 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.28s
#
# 🎯 Trial 70/2000...
#    🔍 Final Train Loss (avg): 0.052290 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.33s
#
# 🎯 Trial 71/2000...
#    🔍 Final Train Loss (avg): 0.063716 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 10.36s
#
# 🎯 Trial 72/2000...
#    🔍 Final Train Loss (avg): 0.055706 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.26s
#
# 🎯 Trial 73/2000...
#    🔍 Final Train Loss (avg): 0.048447 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.25s
#
# 🎯 Trial 74/2000...
#    🔍 Final Train Loss (avg): 0.053722 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.26s
#
# 🎯 Trial 75/2000...
#    🔍 Final Train Loss (avg): 0.056719 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.27s
#
# 🎯 Trial 76/2000...
#    🔍 Final Train Loss (avg): 0.049233 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 10.39s
#
# 🎯 Trial 77/2000...
#    🔍 Final Train Loss (avg): 0.049840 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.43s
#
# 🎯 Trial 78/2000...
#    🔍 Final Train Loss (avg): 0.045687 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.28s
#
# 🎯 Trial 79/2000...
#    🔍 Final Train Loss (avg): 0.050065 | Best so far: 0.045131 | Train Acc: 97.89% | Time: 9.30s
#
# 🎯 Trial 80/2000...
#    🔍 Final Train Loss (avg): 0.058744 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.26s
#
# 🎯 Trial 81/2000...
#    🔍 Final Train Loss (avg): 0.063508 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 10.47s
#
# 🎯 Trial 82/2000...
#    🔍 Final Train Loss (avg): 0.057249 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.33s
#
# 🎯 Trial 83/2000...
#    🔍 Final Train Loss (avg): 0.061801 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.26s
#
# 🎯 Trial 84/2000...
#    🔍 Final Train Loss (avg): 0.053861 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.27s
#
# 🎯 Trial 85/2000...
#    🔍 Final Train Loss (avg): 0.055523 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.28s
#
# 🎯 Trial 86/2000...
#    🔍 Final Train Loss (avg): 0.051277 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 10.40s
#
# 🎯 Trial 87/2000...
#    🔍 Final Train Loss (avg): 0.062346 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.28s
#
# 🎯 Trial 88/2000...
#    🔍 Final Train Loss (avg): 0.058497 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.25s
#
# 🎯 Trial 89/2000...
#    🔍 Final Train Loss (avg): 0.054079 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.20s
#
# 🎯 Trial 90/2000...
#    🔍 Final Train Loss (avg): 0.054351 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 10.36s
#
# 🎯 Trial 91/2000...
#    🔍 Final Train Loss (avg): 0.049467 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.29s
#
# 🎯 Trial 92/2000...
#    🔍 Final Train Loss (avg): 0.051744 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.24s
#
# 🎯 Trial 93/2000...
#    🔍 Final Train Loss (avg): 0.050047 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.23s
#
# 🎯 Trial 94/2000...
#    🔍 Final Train Loss (avg): 0.049321 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.24s
#
# 🎯 Trial 95/2000...
#    🔍 Final Train Loss (avg): 0.052275 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 10.36s
#
# 🎯 Trial 96/2000...
#    🔍 Final Train Loss (avg): 0.053112 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.25s
#
# 🎯 Trial 97/2000...
#    🔍 Final Train Loss (avg): 0.050080 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.21s
#
# 🎯 Trial 98/2000...
#    🔍 Final Train Loss (avg): 0.050070 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.23s
#
# 🎯 Trial 99/2000...
#    🔍 Final Train Loss (avg): 0.054536 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.27s
#
# 🎯 Trial 100/2000...
#    🔍 Final Train Loss (avg): 0.052764 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 10.39s
#
# 🎯 Trial 101/2000...
#    🔍 Final Train Loss (avg): 0.052798 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.23s
#
# 🎯 Trial 102/2000...
#    🔍 Final Train Loss (avg): 0.059651 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.29s
#
# 🎯 Trial 103/2000...
#    🔍 Final Train Loss (avg): 0.049395 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.31s
#
# 🎯 Trial 104/2000...
#    🔍 Final Train Loss (avg): 0.064675 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.26s
#
# 🎯 Trial 105/2000...
#    🔍 Final Train Loss (avg): 0.054555 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 10.39s
#
# 🎯 Trial 106/2000...
#    🔍 Final Train Loss (avg): 0.060312 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.33s
#
# 🎯 Trial 107/2000...
#    🔍 Final Train Loss (avg): 0.048414 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.27s
#
# 🎯 Trial 108/2000...
#    🔍 Final Train Loss (avg): 0.057991 | Best so far: 0.045131 | Train Acc: 92.96% | Time: 9.29s
#
# 🎯 Trial 109/2000...
#    🔍 Final Train Loss (avg): 0.055843 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.26s
#
# 🎯 Trial 110/2000...
#    🔍 Final Train Loss (avg): 0.049789 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 10.45s
#
# 🎯 Trial 111/2000...
#    🔍 Final Train Loss (avg): 0.059876 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.23s
#
# 🎯 Trial 112/2000...
#    🔍 Final Train Loss (avg): 0.061273 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.27s
#
# 🎯 Trial 113/2000...
#    🔍 Final Train Loss (avg): 0.053206 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.27s
#
# 🎯 Trial 114/2000...
#    🔍 Final Train Loss (avg): 0.054976 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.28s
#
# 🎯 Trial 115/2000...
#    🔍 Final Train Loss (avg): 0.060797 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 10.46s
#
# 🎯 Trial 116/2000...
#    🔍 Final Train Loss (avg): 0.050864 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.19s
#
# 🎯 Trial 117/2000...
#    🔍 Final Train Loss (avg): 0.056243 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.29s
#
# 🎯 Trial 118/2000...
#    🔍 Final Train Loss (avg): 0.050866 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.23s
#
# 🎯 Trial 119/2000...
#    🔍 Final Train Loss (avg): 0.051662 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.25s
#
# 🎯 Trial 120/2000...
#    🔍 Final Train Loss (avg): 0.054906 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 10.45s
#
# 🎯 Trial 121/2000...
#    🔍 Final Train Loss (avg): 0.054711 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.27s
#
# 🎯 Trial 122/2000...
#    🔍 Final Train Loss (avg): 0.064097 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.29s
#
# 🎯 Trial 123/2000...
#    🔍 Final Train Loss (avg): 0.075841 | Best so far: 0.045131 | Train Acc: 91.55% | Time: 9.30s
#
# 🎯 Trial 124/2000...
#    🔍 Final Train Loss (avg): 0.052191 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.26s
#
# 🎯 Trial 125/2000...
#    🔍 Final Train Loss (avg): 0.054722 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 10.41s
#
# 🎯 Trial 126/2000...
#    🔍 Final Train Loss (avg): 0.066455 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.25s
#
# 🎯 Trial 127/2000...
#    🔍 Final Train Loss (avg): 0.054804 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.28s
#
# 🎯 Trial 128/2000...
#    🔍 Final Train Loss (avg): 0.051886 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.25s
#
# 🎯 Trial 129/2000...
#    🔍 Final Train Loss (avg): 0.059194 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.19s
#
# 🎯 Trial 130/2000...
#    🔍 Final Train Loss (avg): 0.053271 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 10.43s
#
# 🎯 Trial 131/2000...
#    🔍 Final Train Loss (avg): 0.056305 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.27s
#
# 🎯 Trial 132/2000...
#    🔍 Final Train Loss (avg): 0.061198 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.22s
#
# 🎯 Trial 133/2000...
#    🔍 Final Train Loss (avg): 0.063652 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.26s
#
# 🎯 Trial 134/2000...
#    🔍 Final Train Loss (avg): 0.060686 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.29s
#
# 🎯 Trial 135/2000...
#    🔍 Final Train Loss (avg): 0.051346 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 10.44s
#
# 🎯 Trial 136/2000...
#    🔍 Final Train Loss (avg): 0.050487 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.32s
#
# 🎯 Trial 137/2000...
#    🔍 Final Train Loss (avg): 0.062652 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.28s
#
# 🎯 Trial 138/2000...
#    🔍 Final Train Loss (avg): 0.063903 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.28s
#
# 🎯 Trial 139/2000...
#    🔍 Final Train Loss (avg): 0.062263 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.26s
#
# 🎯 Trial 140/2000...
#    🔍 Final Train Loss (avg): 0.046597 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 10.38s
#
# 🎯 Trial 141/2000...
#    🔍 Final Train Loss (avg): 0.059800 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.29s
#
# 🎯 Trial 142/2000...
#    🔍 Final Train Loss (avg): 0.051295 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.26s
#
# 🎯 Trial 143/2000...
#    🔍 Final Train Loss (avg): 0.065993 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.29s
#
# 🎯 Trial 144/2000...
#    🔍 Final Train Loss (avg): 0.064909 | Best so far: 0.045131 | Train Acc: 92.96% | Time: 9.23s
#
# 🎯 Trial 145/2000...
#    🔍 Final Train Loss (avg): 0.057431 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 10.41s
#
# 🎯 Trial 146/2000...
#    🔍 Final Train Loss (avg): 0.054071 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.38s
#
# 🎯 Trial 147/2000...
#    🔍 Final Train Loss (avg): 0.048815 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.20s
#
# 🎯 Trial 148/2000...
#    🔍 Final Train Loss (avg): 0.048309 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.24s
#
# 🎯 Trial 149/2000...
#    🔍 Final Train Loss (avg): 0.058918 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 10.39s
#
# 🎯 Trial 150/2000...
#    🔍 Final Train Loss (avg): 0.057065 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.33s
#
# 🎯 Trial 151/2000...
#    🔍 Final Train Loss (avg): 0.054824 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.19s
#
# 🎯 Trial 152/2000...
#    🔍 Final Train Loss (avg): 0.049095 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.23s
#
# 🎯 Trial 153/2000...
#    🔍 Final Train Loss (avg): 0.052787 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.21s
#
# 🎯 Trial 154/2000...
#    🔍 Final Train Loss (avg): 0.065266 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 10.42s
#
# 🎯 Trial 155/2000...
#    🔍 Final Train Loss (avg): 0.053392 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.23s
#
# 🎯 Trial 156/2000...
#    🔍 Final Train Loss (avg): 0.052908 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.23s
#
# 🎯 Trial 157/2000...
#    🔍 Final Train Loss (avg): 0.063600 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.26s
#
# 🎯 Trial 158/2000...
#    🔍 Final Train Loss (avg): 0.066724 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.30s
#
# 🎯 Trial 159/2000...
#    🔍 Final Train Loss (avg): 0.054265 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 10.48s
#
# 🎯 Trial 160/2000...
#    🔍 Final Train Loss (avg): 0.058642 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.25s
#
# 🎯 Trial 161/2000...
#    🔍 Final Train Loss (avg): 0.053820 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.26s
#
# 🎯 Trial 162/2000...
#    🔍 Final Train Loss (avg): 0.059208 | Best so far: 0.045131 | Train Acc: 92.96% | Time: 9.26s
#
# 🎯 Trial 163/2000...
#    🔍 Final Train Loss (avg): 0.066805 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.21s
#
# 🎯 Trial 164/2000...
#    🔍 Final Train Loss (avg): 0.057847 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 10.36s
#
# 🎯 Trial 165/2000...
#    🔍 Final Train Loss (avg): 0.049947 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.21s
#
# 🎯 Trial 166/2000...
#    🔍 Final Train Loss (avg): 0.059188 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.28s
#
# 🎯 Trial 167/2000...
#    🔍 Final Train Loss (avg): 0.050536 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.27s
#
# 🎯 Trial 168/2000...
#    🔍 Final Train Loss (avg): 0.053097 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.33s
#
# 🎯 Trial 169/2000...
#    🔍 Final Train Loss (avg): 0.047049 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.25s
#
# 🎯 Trial 170/2000...
#    🔍 Final Train Loss (avg): 0.057007 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.26s
#
# 🎯 Trial 171/2000...
#    🔍 Final Train Loss (avg): 0.065844 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.23s
#
# 🎯 Trial 172/2000...
#    🔍 Final Train Loss (avg): 0.049729 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.32s
#
# 🎯 Trial 173/2000...
#    🔍 Final Train Loss (avg): 0.045867 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.29s
#
# 🎯 Trial 174/2000...
#    🔍 Final Train Loss (avg): 0.052298 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.23s
#
# 🎯 Trial 175/2000...
#    🔍 Final Train Loss (avg): 0.059582 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.37s
#
# 🎯 Trial 176/2000...
#    🔍 Final Train Loss (avg): 0.054271 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.32s
#
# 🎯 Trial 177/2000...
#    🔍 Final Train Loss (avg): 0.052263 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.28s
#
# 🎯 Trial 178/2000...
#    🔍 Final Train Loss (avg): 0.069925 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.33s
#
# 🎯 Trial 179/2000...
#    🔍 Final Train Loss (avg): 0.053339 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 10.47s
#
# 🎯 Trial 180/2000...
#    🔍 Final Train Loss (avg): 0.062869 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.22s
#
# 🎯 Trial 181/2000...
#    🔍 Final Train Loss (avg): 0.067727 | Best so far: 0.045131 | Train Acc: 91.55% | Time: 9.24s
#
# 🎯 Trial 182/2000...
#    🔍 Final Train Loss (avg): 0.051779 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.31s
#
# 🎯 Trial 183/2000...
#    🔍 Final Train Loss (avg): 0.050954 | Best so far: 0.045131 | Train Acc: 97.89% | Time: 9.23s
#
# 🎯 Trial 184/2000...
#    🔍 Final Train Loss (avg): 0.052903 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.24s
#
# 🎯 Trial 185/2000...
#    🔍 Final Train Loss (avg): 0.050942 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.22s
#
# 🎯 Trial 186/2000...
#    🔍 Final Train Loss (avg): 0.057286 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.24s
#
# 🎯 Trial 187/2000...
#    🔍 Final Train Loss (avg): 0.059555 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.35s
#
# 🎯 Trial 188/2000...
#    🔍 Final Train Loss (avg): 0.048435 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.22s
#
# 🎯 Trial 189/2000...
#    🔍 Final Train Loss (avg): 0.047493 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.23s
#
# 🎯 Trial 190/2000...
#    🔍 Final Train Loss (avg): 0.059406 | Best so far: 0.045131 | Train Acc: 92.96% | Time: 9.22s
#
# 🎯 Trial 191/2000...
#    🔍 Final Train Loss (avg): 0.053252 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.27s
#
# 🎯 Trial 192/2000...
#    🔍 Final Train Loss (avg): 0.062943 | Best so far: 0.045131 | Train Acc: 92.96% | Time: 9.27s
#
# 🎯 Trial 193/2000...
#    🔍 Final Train Loss (avg): 0.049362 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 10.35s
#
# 🎯 Trial 194/2000...
#    🔍 Final Train Loss (avg): 0.058899 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.29s
#
# 🎯 Trial 195/2000...
#    🔍 Final Train Loss (avg): 0.049147 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.27s
#
# 🎯 Trial 196/2000...
#    🔍 Final Train Loss (avg): 0.059251 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.22s
#
# 🎯 Trial 197/2000...
#    🔍 Final Train Loss (avg): 0.057715 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.25s
#
# 🎯 Trial 198/2000...
#    🔍 Final Train Loss (avg): 0.047200 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.28s
#
# 🎯 Trial 199/2000...
#    🔍 Final Train Loss (avg): 0.047723 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.26s
#
# 🎯 Trial 200/2000...
#    🔍 Final Train Loss (avg): 0.056398 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.24s
#
# 🎯 Trial 201/2000...
#    🔍 Final Train Loss (avg): 0.060213 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.30s
#
# 🎯 Trial 202/2000...
#    🔍 Final Train Loss (avg): 0.062327 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.26s
#
# 🎯 Trial 203/2000...
#    🔍 Final Train Loss (avg): 0.071252 | Best so far: 0.045131 | Train Acc: 91.55% | Time: 9.31s
#
# 🎯 Trial 204/2000...
#    🔍 Final Train Loss (avg): 0.055588 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.25s
#
# 🎯 Trial 205/2000...
#    🔍 Final Train Loss (avg): 0.050967 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.27s
#
# 🎯 Trial 206/2000...
#    🔍 Final Train Loss (avg): 0.059439 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.22s
#
# 🎯 Trial 207/2000...
#    🔍 Final Train Loss (avg): 0.055667 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.34s
#
# 🎯 Trial 208/2000...
#    🔍 Final Train Loss (avg): 0.057118 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 10.48s
#
# 🎯 Trial 209/2000...
#    🔍 Final Train Loss (avg): 0.066377 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.28s
#
# 🎯 Trial 210/2000...
#    🔍 Final Train Loss (avg): 0.057219 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.31s
#
# 🎯 Trial 211/2000...
#    🔍 Final Train Loss (avg): 0.046354 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.25s
#
# 🎯 Trial 212/2000...
#    🔍 Final Train Loss (avg): 0.055398 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.28s
#
# 🎯 Trial 213/2000...
#    🔍 Final Train Loss (avg): 0.052884 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.28s
#
# 🎯 Trial 214/2000...
#    🔍 Final Train Loss (avg): 0.050159 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.23s
#
# 🎯 Trial 215/2000...
#    🔍 Final Train Loss (avg): 0.049175 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.30s
#
# 🎯 Trial 216/2000...
#    🔍 Final Train Loss (avg): 0.055291 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.27s
#
# 🎯 Trial 217/2000...
#    🔍 Final Train Loss (avg): 0.065582 | Best so far: 0.045131 | Train Acc: 92.96% | Time: 9.25s
#
# 🎯 Trial 218/2000...
#    🔍 Final Train Loss (avg): 0.055866 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.27s
#
# 🎯 Trial 219/2000...
#    🔍 Final Train Loss (avg): 0.053346 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.25s
#
# 🎯 Trial 220/2000...
#    🔍 Final Train Loss (avg): 0.054388 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.24s
#
# 🎯 Trial 221/2000...
#    🔍 Final Train Loss (avg): 0.057825 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.25s
#
# 🎯 Trial 222/2000...
#    🔍 Final Train Loss (avg): 0.058851 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 10.41s
#
# 🎯 Trial 223/2000...
#    🔍 Final Train Loss (avg): 0.051513 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.30s
#
# 🎯 Trial 224/2000...
#    🔍 Final Train Loss (avg): 0.055750 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.19s
#
# 🎯 Trial 225/2000...
#    🔍 Final Train Loss (avg): 0.047567 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.23s
#
# 🎯 Trial 226/2000...
#    🔍 Final Train Loss (avg): 0.053488 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.25s
#
# 🎯 Trial 227/2000...
#    🔍 Final Train Loss (avg): 0.060010 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.21s
#
# 🎯 Trial 228/2000...
#    🔍 Final Train Loss (avg): 0.067284 | Best so far: 0.045131 | Train Acc: 92.96% | Time: 9.28s
#
# 🎯 Trial 229/2000...
#    🔍 Final Train Loss (avg): 0.054181 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.23s
#
# 🎯 Trial 230/2000...
#    🔍 Final Train Loss (avg): 0.054473 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.25s
#
# 🎯 Trial 231/2000...
#    🔍 Final Train Loss (avg): 0.045862 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.26s
#
# 🎯 Trial 232/2000...
#    🔍 Final Train Loss (avg): 0.055228 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.27s
#
# 🎯 Trial 233/2000...
#    🔍 Final Train Loss (avg): 0.053940 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.25s
#
# 🎯 Trial 234/2000...
#    🔍 Final Train Loss (avg): 0.050428 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.19s
#
# 🎯 Trial 235/2000...
#    🔍 Final Train Loss (avg): 0.054545 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.25s
#
# 🎯 Trial 236/2000...
#    🔍 Final Train Loss (avg): 0.053608 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.26s
#
# 🎯 Trial 237/2000...
#    🔍 Final Train Loss (avg): 0.074856 | Best so far: 0.045131 | Train Acc: 92.96% | Time: 9.26s
#
# 🎯 Trial 238/2000...
#    🔍 Final Train Loss (avg): 0.055695 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.23s
#
# 🎯 Trial 239/2000...
#    🔍 Final Train Loss (avg): 0.066041 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.25s
#
# 🎯 Trial 240/2000...
#    🔍 Final Train Loss (avg): 0.048743 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.30s
#
# 🎯 Trial 241/2000...
#    🔍 Final Train Loss (avg): 0.057367 | Best so far: 0.045131 | Train Acc: 92.96% | Time: 9.27s
#
# 🎯 Trial 242/2000...
#    🔍 Final Train Loss (avg): 0.052016 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.30s
#
# 🎯 Trial 243/2000...
#    🔍 Final Train Loss (avg): 0.060135 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.29s
#
# 🎯 Trial 244/2000...
#    🔍 Final Train Loss (avg): 0.057375 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.28s
#
# 🎯 Trial 245/2000...
#    🔍 Final Train Loss (avg): 0.054628 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.24s
#
# 🎯 Trial 246/2000...
#    🔍 Final Train Loss (avg): 0.052327 | Best so far: 0.045131 | Train Acc: 97.89% | Time: 9.22s
#
# 🎯 Trial 247/2000...
#    🔍 Final Train Loss (avg): 0.049626 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.23s
#
# 🎯 Trial 248/2000...
#    🔍 Final Train Loss (avg): 0.054538 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.25s
#
# 🎯 Trial 249/2000...
#    🔍 Final Train Loss (avg): 0.057619 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 10.47s
#
# 🎯 Trial 250/2000...
#    🔍 Final Train Loss (avg): 0.066943 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.30s
#
# 🎯 Trial 251/2000...
#    🔍 Final Train Loss (avg): 0.056635 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.23s
#
# 🎯 Trial 252/2000...
#    🔍 Final Train Loss (avg): 0.060811 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.21s
#
# 🎯 Trial 253/2000...
#    🔍 Final Train Loss (avg): 0.053320 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.27s
#
# 🎯 Trial 254/2000...
#    🔍 Final Train Loss (avg): 0.046140 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.27s
#
# 🎯 Trial 255/2000...
#    🔍 Final Train Loss (avg): 0.058408 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.25s
#
# 🎯 Trial 256/2000...
#    🔍 Final Train Loss (avg): 0.053637 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.32s
#
# 🎯 Trial 257/2000...
#    🔍 Final Train Loss (avg): 0.053185 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.26s
#
# 🎯 Trial 258/2000...
#    🔍 Final Train Loss (avg): 0.060619 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.27s
#
# 🎯 Trial 259/2000...
#    🔍 Final Train Loss (avg): 0.068072 | Best so far: 0.045131 | Train Acc: 91.55% | Time: 9.24s
#
# 🎯 Trial 260/2000...
#    🔍 Final Train Loss (avg): 0.057801 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.22s
#
# 🎯 Trial 261/2000...
#    🔍 Final Train Loss (avg): 0.062011 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.24s
#
# 🎯 Trial 262/2000...
#    🔍 Final Train Loss (avg): 0.050033 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.24s
#
# 🎯 Trial 263/2000...
#    🔍 Final Train Loss (avg): 0.050350 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 10.42s
#
# 🎯 Trial 264/2000...
#    🔍 Final Train Loss (avg): 0.055090 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.29s
#
# 🎯 Trial 265/2000...
#    🔍 Final Train Loss (avg): 0.065519 | Best so far: 0.045131 | Train Acc: 92.25% | Time: 9.22s
#
# 🎯 Trial 266/2000...
#    🔍 Final Train Loss (avg): 0.061557 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.33s
#
# 🎯 Trial 267/2000...
#    🔍 Final Train Loss (avg): 0.047574 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.26s
#
# 🎯 Trial 268/2000...
#    🔍 Final Train Loss (avg): 0.059338 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.32s
#
# 🎯 Trial 269/2000...
#    🔍 Final Train Loss (avg): 0.057665 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.28s
#
# 🎯 Trial 270/2000...
#    🔍 Final Train Loss (avg): 0.053000 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.22s
#
# 🎯 Trial 271/2000...
#    🔍 Final Train Loss (avg): 0.059071 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.30s
#
# 🎯 Trial 272/2000...
#    🔍 Final Train Loss (avg): 0.052728 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.36s
#
# 🎯 Trial 273/2000...
#    🔍 Final Train Loss (avg): 0.064322 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.27s
#
# 🎯 Trial 274/2000...
#    🔍 Final Train Loss (avg): 0.046882 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 12.45s
#
# 🎯 Trial 275/2000...
#    🔍 Final Train Loss (avg): 0.053292 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 32.61s
#
# 🎯 Trial 276/2000...
#    🔍 Final Train Loss (avg): 0.047044 | Best so far: 0.045131 | Train Acc: 97.89% | Time: 9.34s
#
# 🎯 Trial 277/2000...
#    🔍 Final Train Loss (avg): 0.053762 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 30.52s
#
# 🎯 Trial 278/2000...
#    🔍 Final Train Loss (avg): 0.057887 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.38s
#
# 🎯 Trial 279/2000...
#    🔍 Final Train Loss (avg): 0.056993 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 327.73s
#
# 🎯 Trial 280/2000...
#    🔍 Final Train Loss (avg): 0.057064 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.29s
#
# 🎯 Trial 281/2000...
#    🔍 Final Train Loss (avg): 0.050232 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.30s
#
# 🎯 Trial 282/2000...
#    🔍 Final Train Loss (avg): 0.054254 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.36s
#
# 🎯 Trial 283/2000...
#    🔍 Final Train Loss (avg): 0.057177 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.35s
#
# 🎯 Trial 284/2000...
#    🔍 Final Train Loss (avg): 0.059964 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.97s
#
# 🎯 Trial 285/2000...
#    🔍 Final Train Loss (avg): 0.057672 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.32s
#
# 🎯 Trial 286/2000...
#    🔍 Final Train Loss (avg): 0.054025 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 989.00s
#
# 🎯 Trial 287/2000...
#    🔍 Final Train Loss (avg): 0.060665 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 1896.16s
#
# 🎯 Trial 288/2000...
#    🔍 Final Train Loss (avg): 0.069142 | Best so far: 0.045131 | Train Acc: 92.96% | Time: 1406.72s
#
# 🎯 Trial 289/2000...
#    🔍 Final Train Loss (avg): 0.072033 | Best so far: 0.045131 | Train Acc: 92.96% | Time: 9.52s
#
# 🎯 Trial 290/2000...
#    🔍 Final Train Loss (avg): 0.050902 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 48.19s
#
# 🎯 Trial 291/2000...
#    🔍 Final Train Loss (avg): 0.048816 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.27s
#
# 🎯 Trial 292/2000...
#    🔍 Final Train Loss (avg): 0.046587 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 1984.75s
#
# 🎯 Trial 293/2000...
#    🔍 Final Train Loss (avg): 0.054697 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 925.24s
#
# 🎯 Trial 294/2000...
#    🔍 Final Train Loss (avg): 0.056161 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 1954.82s
#
# 🎯 Trial 295/2000...
#    🔍 Final Train Loss (avg): 0.048281 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 10.74s
#
# 🎯 Trial 296/2000...
#    🔍 Final Train Loss (avg): 0.059157 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.80s
#
# 🎯 Trial 297/2000...
#    🔍 Final Train Loss (avg): 0.053367 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.61s
#
# 🎯 Trial 298/2000...
#    🔍 Final Train Loss (avg): 0.047972 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.68s
#
# 🎯 Trial 299/2000...
#    🔍 Final Train Loss (avg): 0.057984 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.61s
#
# 🎯 Trial 300/2000...
#    🔍 Final Train Loss (avg): 0.048597 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.33s
#
# 🎯 Trial 301/2000...
#    🔍 Final Train Loss (avg): 0.061230 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.39s
#
# 🎯 Trial 302/2000...
#    🔍 Final Train Loss (avg): 0.049455 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.54s
#
# 🎯 Trial 303/2000...
#    🔍 Final Train Loss (avg): 0.063571 | Best so far: 0.045131 | Train Acc: 97.89% | Time: 9.34s
#
# 🎯 Trial 304/2000...
#    🔍 Final Train Loss (avg): 0.067848 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.97s
#
# 🎯 Trial 305/2000...
#    🔍 Final Train Loss (avg): 0.056148 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.56s
#
# 🎯 Trial 306/2000...
#    🔍 Final Train Loss (avg): 0.054675 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.42s
#
# 🎯 Trial 307/2000...
#    🔍 Final Train Loss (avg): 0.055245 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 10.93s
#
# 🎯 Trial 308/2000...
#    🔍 Final Train Loss (avg): 0.048482 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.85s
#
# 🎯 Trial 309/2000...
#    🔍 Final Train Loss (avg): 0.051594 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.42s
#
# 🎯 Trial 310/2000...
#    🔍 Final Train Loss (avg): 0.051666 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.70s
#
# 🎯 Trial 311/2000...
#    🔍 Final Train Loss (avg): 0.053188 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 10.00s
#
# 🎯 Trial 312/2000...
#    🔍 Final Train Loss (avg): 0.053953 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.43s
#
# 🎯 Trial 313/2000...
#    🔍 Final Train Loss (avg): 0.046900 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.51s
#
# 🎯 Trial 314/2000...
#    🔍 Final Train Loss (avg): 0.067235 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.64s
#
# 🎯 Trial 315/2000...
#    🔍 Final Train Loss (avg): 0.048956 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.61s
#
# 🎯 Trial 316/2000...
#    🔍 Final Train Loss (avg): 0.067719 | Best so far: 0.045131 | Train Acc: 91.55% | Time: 9.75s
#
# 🎯 Trial 317/2000...
#    🔍 Final Train Loss (avg): 0.059071 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 10.16s
#
# 🎯 Trial 318/2000...
#    🔍 Final Train Loss (avg): 0.053843 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.72s
#
# 🎯 Trial 319/2000...
#    🔍 Final Train Loss (avg): 0.055951 | Best so far: 0.045131 | Train Acc: 92.96% | Time: 9.45s
#
# 🎯 Trial 320/2000...
#    🔍 Final Train Loss (avg): 0.065942 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.48s
#
# 🎯 Trial 321/2000...
#    🔍 Final Train Loss (avg): 0.058781 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.57s
#
# 🎯 Trial 322/2000...
#    🔍 Final Train Loss (avg): 0.069577 | Best so far: 0.045131 | Train Acc: 92.25% | Time: 9.78s
#
# 🎯 Trial 323/2000...
#    🔍 Final Train Loss (avg): 0.057337 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.93s
#
# 🎯 Trial 324/2000...
#    🔍 Final Train Loss (avg): 0.050422 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 10.80s
#
# 🎯 Trial 325/2000...
#    🔍 Final Train Loss (avg): 0.057565 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.73s
#
# 🎯 Trial 326/2000...
#    🔍 Final Train Loss (avg): 0.047689 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.59s
#
# 🎯 Trial 327/2000...
#    🔍 Final Train Loss (avg): 0.057703 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 10.04s
#
# 🎯 Trial 328/2000...
#    🔍 Final Train Loss (avg): 0.055253 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.51s
#
# 🎯 Trial 329/2000...
#    🔍 Final Train Loss (avg): 0.059504 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.82s
#
# 🎯 Trial 330/2000...
#    🔍 Final Train Loss (avg): 0.057786 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.39s
#
# 🎯 Trial 331/2000...
#    🔍 Final Train Loss (avg): 0.055251 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.38s
#
# 🎯 Trial 332/2000...
#    🔍 Final Train Loss (avg): 0.050573 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.37s
#
# 🎯 Trial 333/2000...
#    🔍 Final Train Loss (avg): 0.049153 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.84s
#
# 🎯 Trial 334/2000...
#    🔍 Final Train Loss (avg): 0.046888 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.45s
#
# 🎯 Trial 335/2000...
#    🔍 Final Train Loss (avg): 0.056746 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.42s
#
# 🎯 Trial 336/2000...
#    🔍 Final Train Loss (avg): 0.061092 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.70s
#
# 🎯 Trial 337/2000...
#    🔍 Final Train Loss (avg): 0.060435 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 10.05s
#
# 🎯 Trial 338/2000...
#    🔍 Final Train Loss (avg): 0.046218 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.64s
#
# 🎯 Trial 339/2000...
#    🔍 Final Train Loss (avg): 0.058373 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.82s
#
# 🎯 Trial 340/2000...
#    🔍 Final Train Loss (avg): 0.079012 | Best so far: 0.045131 | Train Acc: 91.55% | Time: 10.13s
#
# 🎯 Trial 341/2000...
#    🔍 Final Train Loss (avg): 0.052003 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.33s
#
# 🎯 Trial 342/2000...
#    🔍 Final Train Loss (avg): 0.057143 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 10.39s
#
# 🎯 Trial 343/2000...
#    🔍 Final Train Loss (avg): 0.065421 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.69s
#
# 🎯 Trial 344/2000...
#    🔍 Final Train Loss (avg): 0.067340 | Best so far: 0.045131 | Train Acc: 92.96% | Time: 10.12s
#
# 🎯 Trial 345/2000...
#    🔍 Final Train Loss (avg): 0.051039 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.76s
#
# 🎯 Trial 346/2000...
#    🔍 Final Train Loss (avg): 0.049935 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.35s
#
# 🎯 Trial 347/2000...
#    🔍 Final Train Loss (avg): 0.056723 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.88s
#
# 🎯 Trial 348/2000...
#    🔍 Final Train Loss (avg): 0.059866 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.96s
#
# 🎯 Trial 349/2000...
#    🔍 Final Train Loss (avg): 0.047539 | Best so far: 0.045131 | Train Acc: 97.89% | Time: 9.68s
#
# 🎯 Trial 350/2000...
#    🔍 Final Train Loss (avg): 0.054550 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.60s
#
# 🎯 Trial 351/2000...
#    🔍 Final Train Loss (avg): 0.058819 | Best so far: 0.045131 | Train Acc: 92.25% | Time: 9.62s
#
# 🎯 Trial 352/2000...
#    🔍 Final Train Loss (avg): 0.050284 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.57s
#
# 🎯 Trial 353/2000...
#    🔍 Final Train Loss (avg): 0.054493 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.57s
#
# 🎯 Trial 354/2000...
#    🔍 Final Train Loss (avg): 0.054729 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.57s
#
# 🎯 Trial 355/2000...
#    🔍 Final Train Loss (avg): 0.051590 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.36s
#
# 🎯 Trial 356/2000...
#    🔍 Final Train Loss (avg): 0.056888 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.36s
#
# 🎯 Trial 357/2000...
#    🔍 Final Train Loss (avg): 0.056931 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.30s
#
# 🎯 Trial 358/2000...
#    🔍 Final Train Loss (avg): 0.059321 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.27s
#
# 🎯 Trial 359/2000...
#    🔍 Final Train Loss (avg): 0.048575 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.42s
#
# 🎯 Trial 360/2000...
#    🔍 Final Train Loss (avg): 0.059535 | Best so far: 0.045131 | Train Acc: 92.96% | Time: 9.31s
#
# 🎯 Trial 361/2000...
#    🔍 Final Train Loss (avg): 0.054929 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.40s
#
# 🎯 Trial 362/2000...
#    🔍 Final Train Loss (avg): 0.057625 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.61s
#
# 🎯 Trial 363/2000...
#    🔍 Final Train Loss (avg): 0.061202 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 10.18s
#
# 🎯 Trial 364/2000...
#    🔍 Final Train Loss (avg): 0.053796 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.81s
#
# 🎯 Trial 365/2000...
#    🔍 Final Train Loss (avg): 0.062249 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.41s
#
# 🎯 Trial 366/2000...
#    🔍 Final Train Loss (avg): 0.059686 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.35s
#
# 🎯 Trial 367/2000...
#    🔍 Final Train Loss (avg): 0.055591 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.47s
#
# 🎯 Trial 368/2000...
#    🔍 Final Train Loss (avg): 0.060477 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.33s
#
# 🎯 Trial 369/2000...
#    🔍 Final Train Loss (avg): 0.060241 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.53s
#
# 🎯 Trial 370/2000...
#    🔍 Final Train Loss (avg): 0.056107 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 9.85s
#
# 🎯 Trial 371/2000...
#    🔍 Final Train Loss (avg): 0.051474 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.93s
#
# 🎯 Trial 372/2000...
#    🔍 Final Train Loss (avg): 0.060543 | Best so far: 0.045131 | Train Acc: 91.55% | Time: 9.99s
#
# 🎯 Trial 373/2000...
#    🔍 Final Train Loss (avg): 0.056851 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 9.36s
#
# 🎯 Trial 374/2000...
#    🔍 Final Train Loss (avg): 0.051716 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.67s
#
# 🎯 Trial 375/2000...
#    🔍 Final Train Loss (avg): 0.065961 | Best so far: 0.045131 | Train Acc: 91.55% | Time: 9.31s
#
# 🎯 Trial 376/2000...
#    🔍 Final Train Loss (avg): 0.058421 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.58s
#
# 🎯 Trial 377/2000...
#    🔍 Final Train Loss (avg): 0.056315 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.38s
#
# 🎯 Trial 378/2000...
#    🔍 Final Train Loss (avg): 0.059562 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 9.35s
#
# 🎯 Trial 379/2000...
#    🔍 Final Train Loss (avg): 0.054465 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 10.90s
#
# 🎯 Trial 380/2000...
#    🔍 Final Train Loss (avg): 0.053733 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 9.72s
#
# 🎯 Trial 381/2000...
#    🔍 Final Train Loss (avg): 0.056674 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.58s
#
# 🎯 Trial 382/2000...
#    🔍 Final Train Loss (avg): 0.057718 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 9.41s
#
# 🎯 Trial 383/2000...
#    🔍 Final Train Loss (avg): 0.062103 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.31s
#
# 🎯 Trial 384/2000...
#    🔍 Final Train Loss (avg): 0.059931 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 8.53s
#
# 🎯 Trial 385/2000...
#    🔍 Final Train Loss (avg): 0.060170 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 8.73s
#
# 🎯 Trial 386/2000...
#    🔍 Final Train Loss (avg): 0.049930 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 8.78s
#
# 🎯 Trial 387/2000...
#    🔍 Final Train Loss (avg): 0.055985 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 8.55s
#
# 🎯 Trial 388/2000...
#    🔍 Final Train Loss (avg): 0.057669 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 8.46s
#
# 🎯 Trial 389/2000...
#    🔍 Final Train Loss (avg): 0.048931 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 8.95s
#
# 🎯 Trial 390/2000...
#    🔍 Final Train Loss (avg): 0.072052 | Best so far: 0.045131 | Train Acc: 92.25% | Time: 8.67s
#
# 🎯 Trial 391/2000...
#    🔍 Final Train Loss (avg): 0.057122 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.00s
#
# 🎯 Trial 392/2000...
#    🔍 Final Train Loss (avg): 0.049760 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 8.59s
#
# 🎯 Trial 393/2000...
#    🔍 Final Train Loss (avg): 0.053284 | Best so far: 0.045131 | Train Acc: 93.66% | Time: 8.34s
#
# 🎯 Trial 394/2000...
#    🔍 Final Train Loss (avg): 0.051496 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 8.38s
#
# 🎯 Trial 395/2000...
#    🔍 Final Train Loss (avg): 0.054058 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 8.39s
#
# 🎯 Trial 396/2000...
#    🔍 Final Train Loss (avg): 0.053887 | Best so far: 0.045131 | Train Acc: 97.18% | Time: 8.69s
#
# 🎯 Trial 397/2000...
#    🔍 Final Train Loss (avg): 0.048377 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.05s
#
# 🎯 Trial 398/2000...
#    🔍 Final Train Loss (avg): 0.051119 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 9.12s
#
# 🎯 Trial 399/2000...
#    🔍 Final Train Loss (avg): 0.056128 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 8.66s
#
# 🎯 Trial 400/2000...
#    🔍 Final Train Loss (avg): 0.052185 | Best so far: 0.045131 | Train Acc: 95.77% | Time: 8.69s
#
# 🎯 Trial 401/2000...
#    🔍 Final Train Loss (avg): 0.055111 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 8.44s
#
# 🎯 Trial 402/2000...
#    🔍 Final Train Loss (avg): 0.055437 | Best so far: 0.045131 | Train Acc: 95.07% | Time: 8.73s
#
# 🎯 Trial 403/2000...
#    🔍 Final Train Loss (avg): 0.050319 | Best so far: 0.045131 | Train Acc: 96.48% | Time: 8.55s
#
# 🎯 Trial 404/2000...
#    🔍 Final Train Loss (avg): 0.068700 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 8.42s
#
# 🎯 Trial 405/2000...
#    🔍 Final Train Loss (avg): 0.050860 | Best so far: 0.045131 | Train Acc: 94.37% | Time: 8.31s
#
# 🎯 Trial 406/2000...
#    🔍 Final Train Loss (avg): 0.043642 | Best so far: 0.043642 | Train Acc: 97.18% | Time: 8.47s
#
# 🎯 Trial 407/2000...
#    🔍 Final Train Loss (avg): 0.048955 | Best so far: 0.043642 | Train Acc: 94.37% | Time: 8.82s
#
# 🎯 Trial 408/2000...
#    🔍 Final Train Loss (avg): 0.056812 | Best so far: 0.043642 | Train Acc: 96.48% | Time: 8.89s
#
# 🎯 Trial 409/2000...
#    🔍 Final Train Loss (avg): 0.049919 | Best so far: 0.043642 | Train Acc: 96.48% | Time: 8.45s
#
# 🎯 Trial 410/2000...
#    🔍 Final Train Loss (avg): 0.056155 | Best so far: 0.043642 | Train Acc: 96.48% | Time: 8.82s
#
# 🎯 Trial 411/2000...
# ...
#
# 🎯 Trial 825/2000...
#    🔍 Final Train Loss (avg): 0.050759 | Best so far: 0.040896 | Train Acc: 97.18% | Time: 9.58s
#
# 🎯 Trial 826/2000...
#    🔍 Final Train Loss (avg): 0.062031 | Best so far: 0.040896 | Train Acc: 93.66% | Time: 9.60s
#
# 🎯 Trial 827/2000...
#    🔍 Final Train Loss (avg): 0.050330 | Best so far: 0.040896 | Train Acc: 96.48% | Time: 9.59s
#
# 🎯 Trial 828/2000...
#    🔍 Final Train Loss (avg): 0.053024 | Best so far: 0.040896 | Train Acc: 92.96% | Time: 9.49s
#
# 🎯 Trial 829/2000...
#    🔍 Final Train Loss (avg): 0.056473 | Best so far: 0.040896 | Train Acc: 95.07% | Time: 9.84s
#
# 🎯 Trial 830/2000...
#    🔍 Final Train Loss (avg): 0.066054 | Best so far: 0.040896 | Train Acc: 94.37% | Time: 9.62s
#
# 🎯 Trial 831/2000...
#    🔍 Final Train Loss (avg): 0.064073 | Best so far: 0.040896 | Train Acc: 95.07% | Time: 9.73s
#
# 🎯 Trial 832/2000...
#    🔍 Final Train Loss (avg): 0.062222 | Best so far: 0.040896 | Train Acc: 94.37% | Time: 9.97s
#
# 🎯 Trial 833/2000...
#    🔍 Final Train Loss (avg): 0.051186 | Best so far: 0.040896 | Train Acc: 93.66% | Time: 9.65s
#
# 🎯 Trial 834/2000...
#    🔍 Final Train Loss (avg): 0.050293 | Best so far: 0.040896 | Train Acc: 94.37% | Time: 9.82s
#
# 🎯 Trial 835/2000...
#    🔍 Final Train Loss (avg): 0.064972 | Best so far: 0.040896 | Train Acc: 93.66% | Time: 9.37s
#
# 🎯 Trial 836/2000...
#    🔍 Final Train Loss (avg): 0.049334 | Best so far: 0.040896 | Train Acc: 95.07% | Time: 9.22s
#
# 🎯 Trial 837/2000...
#    🔍 Final Train Loss (avg): 0.050609 | Best so far: 0.040896 | Train Acc: 96.48% | Time: 9.26s
#
# 🎯 Trial 838/2000...
#    🔍 Final Train Loss (avg): 0.055567 | Best so far: 0.040896 | Train Acc: 95.07% | Time: 9.33s
#
# 🎯 Trial 839/2000...
#    🔍 Final Train Loss (avg): 0.057000 | Best so far: 0.040896 | Train Acc: 94.37% | Time: 9.27s
#
# 🎯 Trial 840/2000...
#    🔍 Final Train Loss (avg): 0.055632 | Best so far: 0.040896 | Train Acc: 94.37% | Time: 9.27s
#
# 🎯 Trial 841/2000...
#    🔍 Final Train Loss (avg): 0.049214 | Best so far: 0.040896 | Train Acc: 95.07% | Time: 9.25s
#
# 🎯 Trial 842/2000...
#    🔍 Final Train Loss (avg): 0.051311 | Best so far: 0.040896 | Train Acc: 95.77% | Time: 9.23s
#
# 🎯 Trial 843/2000...
#    🔍 Final Train Loss (avg): 0.040292 | Best so far: 0.040292 | Train Acc: 97.89% | Time: 9.23s
#
# 🎯 Trial 844/2000...
#    🔍 Final Train Loss (avg): 0.049524 | Best so far: 0.040292 | Train Acc: 96.48% | Time: 9.39s
#
# 🎯 Trial 845/2000...
#    🔍 Final Train Loss (avg): 0.053501 | Best so far: 0.040292 | Train Acc: 96.48% | Time: 9.44s
#
# 🎯 Trial 846/2000...
#    🔍 Final Train Loss (avg): 0.054705 | Best so far: 0.040292 | Train Acc: 94.37% | Time: 9.52s
#
# 🎯 Trial 847/2000...
#    🔍 Final Train Loss (avg): 0.048212 | Best so far: 0.040292 | Train Acc: 97.18% | Time: 9.59s
#
# 🎯 Trial 848/2000...
#    🔍 Final Train Loss (avg): 0.052871 | Best so far: 0.040292 | Train Acc: 96.48% | Time: 10.07s
#
# 🎯 Trial 849/2000...
#    🔍 Final Train Loss (avg): 0.049543 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 9.83s
#
# 🎯 Trial 850/2000...
#    🔍 Final Train Loss (avg): 0.056798 | Best so far: 0.040292 | Train Acc: 94.37% | Time: 9.51s
#
# 🎯 Trial 851/2000...
#    🔍 Final Train Loss (avg): 0.056758 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.51s
#
# 🎯 Trial 852/2000...
#    🔍 Final Train Loss (avg): 0.066758 | Best so far: 0.040292 | Train Acc: 92.96% | Time: 9.24s
#
# 🎯 Trial 853/2000...
#    🔍 Final Train Loss (avg): 0.063577 | Best so far: 0.040292 | Train Acc: 92.96% | Time: 9.28s
#
# 🎯 Trial 854/2000...
#    🔍 Final Train Loss (avg): 0.058609 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.34s
#
# 🎯 Trial 855/2000...
#    🔍 Final Train Loss (avg): 0.060441 | Best so far: 0.040292 | Train Acc: 93.66% | Time: 9.29s
#
# 🎯 Trial 856/2000...
#    🔍 Final Train Loss (avg): 0.060888 | Best so far: 0.040292 | Train Acc: 94.37% | Time: 9.20s
#
# 🎯 Trial 857/2000...
#    🔍 Final Train Loss (avg): 0.052990 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.25s
#
# 🎯 Trial 858/2000...
#    🔍 Final Train Loss (avg): 0.045101 | Best so far: 0.040292 | Train Acc: 96.48% | Time: 9.38s
#
# 🎯 Trial 859/2000...
#    🔍 Final Train Loss (avg): 0.052100 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 9.70s
#
# 🎯 Trial 860/2000...
#    🔍 Final Train Loss (avg): 0.057694 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 9.92s
#
# 🎯 Trial 861/2000...
#    🔍 Final Train Loss (avg): 0.062466 | Best so far: 0.040292 | Train Acc: 94.37% | Time: 9.98s
#
# 🎯 Trial 862/2000...
#    🔍 Final Train Loss (avg): 0.052698 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.77s
#
# 🎯 Trial 863/2000...
#    🔍 Final Train Loss (avg): 0.060081 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.42s
#
# 🎯 Trial 864/2000...
#    🔍 Final Train Loss (avg): 0.048401 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 9.73s
#
# 🎯 Trial 865/2000...
#    🔍 Final Train Loss (avg): 0.049132 | Best so far: 0.040292 | Train Acc: 97.18% | Time: 9.33s
#
# 🎯 Trial 866/2000...
#    🔍 Final Train Loss (avg): 0.054476 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 9.22s
#
# 🎯 Trial 867/2000...
#    🔍 Final Train Loss (avg): 0.056112 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.46s
#
# 🎯 Trial 868/2000...
#    🔍 Final Train Loss (avg): 0.052528 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.59s
#
# 🎯 Trial 869/2000...
#    🔍 Final Train Loss (avg): 0.045748 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 10.09s
#
# 🎯 Trial 870/2000...
#    🔍 Final Train Loss (avg): 0.051131 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 10.47s
#
# 🎯 Trial 871/2000...
#    🔍 Final Train Loss (avg): 0.053685 | Best so far: 0.040292 | Train Acc: 97.18% | Time: 9.81s
#
# 🎯 Trial 872/2000...
#    🔍 Final Train Loss (avg): 0.065870 | Best so far: 0.040292 | Train Acc: 94.37% | Time: 9.51s
#
# 🎯 Trial 873/2000...
#    🔍 Final Train Loss (avg): 0.050667 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 9.37s
#
# 🎯 Trial 874/2000...
#    🔍 Final Train Loss (avg): 0.053721 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 9.22s
#
# 🎯 Trial 875/2000...
#    🔍 Final Train Loss (avg): 0.070102 | Best so far: 0.040292 | Train Acc: 94.37% | Time: 9.56s
#
# 🎯 Trial 876/2000...
#    🔍 Final Train Loss (avg): 0.064231 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.54s
#
# 🎯 Trial 877/2000...
#    🔍 Final Train Loss (avg): 0.054451 | Best so far: 0.040292 | Train Acc: 96.48% | Time: 9.28s
#
# 🎯 Trial 878/2000...
#    🔍 Final Train Loss (avg): 0.052495 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.54s
#
# 🎯 Trial 879/2000...
#    🔍 Final Train Loss (avg): 0.058214 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 9.39s
#
# 🎯 Trial 880/2000...
#    🔍 Final Train Loss (avg): 0.050478 | Best so far: 0.040292 | Train Acc: 96.48% | Time: 9.35s
#
# 🎯 Trial 881/2000...
#    🔍 Final Train Loss (avg): 0.051633 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.67s
#
# 🎯 Trial 882/2000...
#    🔍 Final Train Loss (avg): 0.063400 | Best so far: 0.040292 | Train Acc: 94.37% | Time: 9.49s
#
# 🎯 Trial 883/2000...
#    🔍 Final Train Loss (avg): 0.061887 | Best so far: 0.040292 | Train Acc: 92.96% | Time: 9.54s
#
# 🎯 Trial 884/2000...
#    🔍 Final Train Loss (avg): 0.056586 | Best so far: 0.040292 | Train Acc: 93.66% | Time: 9.66s
#
# 🎯 Trial 885/2000...
#    🔍 Final Train Loss (avg): 0.057212 | Best so far: 0.040292 | Train Acc: 93.66% | Time: 10.06s
#
# 🎯 Trial 886/2000...
#    🔍 Final Train Loss (avg): 0.058081 | Best so far: 0.040292 | Train Acc: 93.66% | Time: 11.01s
#
# 🎯 Trial 887/2000...
#    🔍 Final Train Loss (avg): 0.052347 | Best so far: 0.040292 | Train Acc: 97.18% | Time: 10.64s
#
# 🎯 Trial 888/2000...
#    🔍 Final Train Loss (avg): 0.056862 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.63s
#
# 🎯 Trial 889/2000...
#    🔍 Final Train Loss (avg): 0.053455 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 9.45s
#
# 🎯 Trial 890/2000...
#    🔍 Final Train Loss (avg): 0.048938 | Best so far: 0.040292 | Train Acc: 96.48% | Time: 9.22s
#
# 🎯 Trial 891/2000...
#    🔍 Final Train Loss (avg): 0.062806 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.28s
#
# 🎯 Trial 892/2000...
#    🔍 Final Train Loss (avg): 0.051940 | Best so far: 0.040292 | Train Acc: 94.37% | Time: 9.28s
#
# 🎯 Trial 893/2000...
#    🔍 Final Train Loss (avg): 0.064809 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.19s
#
# 🎯 Trial 894/2000...
#    🔍 Final Train Loss (avg): 0.063724 | Best so far: 0.040292 | Train Acc: 93.66% | Time: 9.32s
#
# 🎯 Trial 895/2000...
#    🔍 Final Train Loss (avg): 0.058466 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.62s
#
# 🎯 Trial 896/2000...
#    🔍 Final Train Loss (avg): 0.051331 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.42s
#
# 🎯 Trial 897/2000...
#    🔍 Final Train Loss (avg): 0.055083 | Best so far: 0.040292 | Train Acc: 96.48% | Time: 9.32s
#
# 🎯 Trial 898/2000...
#    🔍 Final Train Loss (avg): 0.045318 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 9.58s
#
# 🎯 Trial 899/2000...
#    🔍 Final Train Loss (avg): 0.065303 | Best so far: 0.040292 | Train Acc: 94.37% | Time: 9.26s
#
# 🎯 Trial 900/2000...
#    🔍 Final Train Loss (avg): 0.066849 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.26s
#
# 🎯 Trial 901/2000...
#    🔍 Final Train Loss (avg): 0.042575 | Best so far: 0.040292 | Train Acc: 97.89% | Time: 9.37s
#
# 🎯 Trial 902/2000...
#    🔍 Final Train Loss (avg): 0.064602 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 9.32s
#
# 🎯 Trial 903/2000...
#    🔍 Final Train Loss (avg): 0.053823 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.27s
#
# 🎯 Trial 904/2000...
#    🔍 Final Train Loss (avg): 0.062850 | Best so far: 0.040292 | Train Acc: 93.66% | Time: 9.24s
#
# 🎯 Trial 905/2000...
#    🔍 Final Train Loss (avg): 0.057116 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.33s
#
# 🎯 Trial 906/2000...
#    🔍 Final Train Loss (avg): 0.055622 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.31s
#
# 🎯 Trial 907/2000...
#    🔍 Final Train Loss (avg): 0.062665 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.42s
#
# 🎯 Trial 908/2000...
#    🔍 Final Train Loss (avg): 0.052682 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 9.31s
#
# 🎯 Trial 909/2000...
#    🔍 Final Train Loss (avg): 0.047116 | Best so far: 0.040292 | Train Acc: 96.48% | Time: 8.77s
#
# 🎯 Trial 910/2000...
#    🔍 Final Train Loss (avg): 0.056357 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 8.96s
#
# 🎯 Trial 911/2000...
#    🔍 Final Train Loss (avg): 0.048479 | Best so far: 0.040292 | Train Acc: 97.18% | Time: 8.91s
#
# 🎯 Trial 912/2000...
#    🔍 Final Train Loss (avg): 0.068659 | Best so far: 0.040292 | Train Acc: 92.96% | Time: 8.65s
#
# 🎯 Trial 913/2000...
#    🔍 Final Train Loss (avg): 0.070664 | Best so far: 0.040292 | Train Acc: 92.25% | Time: 8.83s
#
# 🎯 Trial 914/2000...
#    🔍 Final Train Loss (avg): 0.053566 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 8.71s
#
# 🎯 Trial 915/2000...
#    🔍 Final Train Loss (avg): 0.053648 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.01s
#
# 🎯 Trial 916/2000...
#    🔍 Final Train Loss (avg): 0.054142 | Best so far: 0.040292 | Train Acc: 94.37% | Time: 8.86s
#
# 🎯 Trial 917/2000...
#    🔍 Final Train Loss (avg): 0.048745 | Best so far: 0.040292 | Train Acc: 97.18% | Time: 8.93s
#
# 🎯 Trial 918/2000...
#    🔍 Final Train Loss (avg): 0.053165 | Best so far: 0.040292 | Train Acc: 94.37% | Time: 8.63s
#
# 🎯 Trial 919/2000...
#    🔍 Final Train Loss (avg): 0.057525 | Best so far: 0.040292 | Train Acc: 94.37% | Time: 8.70s
#
# 🎯 Trial 920/2000...
#    🔍 Final Train Loss (avg): 0.048611 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 8.74s
#
# 🎯 Trial 921/2000...
#    🔍 Final Train Loss (avg): 0.051827 | Best so far: 0.040292 | Train Acc: 96.48% | Time: 8.66s
#
# 🎯 Trial 922/2000...
#    🔍 Final Train Loss (avg): 0.046173 | Best so far: 0.040292 | Train Acc: 96.48% | Time: 9.01s
#
# 🎯 Trial 923/2000...
#    🔍 Final Train Loss (avg): 0.056072 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 8.78s
#
# 🎯 Trial 924/2000...
#    🔍 Final Train Loss (avg): 0.048770 | Best so far: 0.040292 | Train Acc: 97.18% | Time: 8.91s
#
# 🎯 Trial 925/2000...
#    🔍 Final Train Loss (avg): 0.053989 | Best so far: 0.040292 | Train Acc: 94.37% | Time: 8.90s
#
# 🎯 Trial 926/2000...
#    🔍 Final Train Loss (avg): 0.055640 | Best so far: 0.040292 | Train Acc: 94.37% | Time: 8.88s
#
# 🎯 Trial 927/2000...
#    🔍 Final Train Loss (avg): 0.050192 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 8.78s
#
# 🎯 Trial 928/2000...
#    🔍 Final Train Loss (avg): 0.056857 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 8.68s
#
# 🎯 Trial 929/2000...
#    🔍 Final Train Loss (avg): 0.048777 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 9.06s
#
# 🎯 Trial 930/2000...
#    🔍 Final Train Loss (avg): 0.051252 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 9.67s
#
# 🎯 Trial 931/2000...
#    🔍 Final Train Loss (avg): 0.051386 | Best so far: 0.040292 | Train Acc: 93.66% | Time: 8.99s
#
# 🎯 Trial 932/2000...
#    🔍 Final Train Loss (avg): 0.055518 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 8.86s
#
# 🎯 Trial 933/2000...
#    🔍 Final Train Loss (avg): 0.065299 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.06s
#
# 🎯 Trial 934/2000...
#    🔍 Final Train Loss (avg): 0.051339 | Best so far: 0.040292 | Train Acc: 96.48% | Time: 9.04s
#
# 🎯 Trial 935/2000...
#    🔍 Final Train Loss (avg): 0.051744 | Best so far: 0.040292 | Train Acc: 96.48% | Time: 8.86s
#
# 🎯 Trial 936/2000...
#    🔍 Final Train Loss (avg): 0.059781 | Best so far: 0.040292 | Train Acc: 93.66% | Time: 9.20s
#
# 🎯 Trial 937/2000...
#    🔍 Final Train Loss (avg): 0.063847 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 9.18s
#
# 🎯 Trial 938/2000...
#    🔍 Final Train Loss (avg): 0.051789 | Best so far: 0.040292 | Train Acc: 94.37% | Time: 8.71s
#
# 🎯 Trial 939/2000...
#    🔍 Final Train Loss (avg): 0.055990 | Best so far: 0.040292 | Train Acc: 97.18% | Time: 8.82s
#
# 🎯 Trial 940/2000...
#    🔍 Final Train Loss (avg): 0.061223 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 8.92s
#
# 🎯 Trial 941/2000...
#    🔍 Final Train Loss (avg): 0.050439 | Best so far: 0.040292 | Train Acc: 97.18% | Time: 8.66s
#
# 🎯 Trial 942/2000...
#    🔍 Final Train Loss (avg): 0.057548 | Best so far: 0.040292 | Train Acc: 93.66% | Time: 8.65s
#
# 🎯 Trial 943/2000...
#    🔍 Final Train Loss (avg): 0.049126 | Best so far: 0.040292 | Train Acc: 97.89% | Time: 10.17s
#
# 🎯 Trial 944/2000...
#    🔍 Final Train Loss (avg): 0.049354 | Best so far: 0.040292 | Train Acc: 98.59% | Time: 8.97s
#
# 🎯 Trial 945/2000...
#    🔍 Final Train Loss (avg): 0.067472 | Best so far: 0.040292 | Train Acc: 92.25% | Time: 8.74s
#
# 🎯 Trial 946/2000...
#    🔍 Final Train Loss (avg): 0.056442 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 8.61s
#
# 🎯 Trial 947/2000...
#    🔍 Final Train Loss (avg): 0.053026 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 8.64s
#
# 🎯 Trial 948/2000...
#    🔍 Final Train Loss (avg): 0.066455 | Best so far: 0.040292 | Train Acc: 94.37% | Time: 9.18s
#
# 🎯 Trial 949/2000...
#    🔍 Final Train Loss (avg): 0.059576 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 8.69s
#
# 🎯 Trial 950/2000...
#    🔍 Final Train Loss (avg): 0.061548 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 8.71s
#
# 🎯 Trial 951/2000...
#    🔍 Final Train Loss (avg): 0.058369 | Best so far: 0.040292 | Train Acc: 95.77% | Time: 9.08s
#
# 🎯 Trial 952/2000...
#    🔍 Final Train Loss (avg): 0.045186 | Best so far: 0.040292 | Train Acc: 97.18% | Time: 8.73s
#
# 🎯 Trial 953/2000...
#    🔍 Final Train Loss (avg): 0.060292 | Best so far: 0.040292 | Train Acc: 96.48% | Time: 8.75s
#
# 🎯 Trial 954/2000...
#    🔍 Final Train Loss (avg): 0.055101 | Best so far: 0.040292 | Train Acc: 96.48% | Time: 8.66s
#
# 🎯 Trial 955/2000...
#    🔍 Final Train Loss (avg): 0.061720 | Best so far: 0.040292 | Train Acc: 96.48% | Time: 8.76s
#
# 🎯 Trial 956/2000...
#    🔍 Final Train Loss (avg): 0.055633 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 8.67s
#
# 🎯 Trial 957/2000...
#    🔍 Final Train Loss (avg): 0.064159 | Best so far: 0.040292 | Train Acc: 93.66% | Time: 8.74s
#
# 🎯 Trial 958/2000...
#    🔍 Final Train Loss (avg): 0.055958 | Best so far: 0.040292 | Train Acc: 95.07% | Time: 8.73s
#
# 🎯 Trial 959/2000...
#    🔍 Final Train Loss (avg): 0.044731 | Best so far: 0.040292 | Train Acc: 96.48% | Time: 8.90s
#
# 🎯 Trial 960/2000...
#    🔍 Final Train Loss (avg): 0.059865 | Best so far: 0.040292 | Train Acc: 94.37% | Time: 8.84s
#
# 🎯 Trial 961/2000...
