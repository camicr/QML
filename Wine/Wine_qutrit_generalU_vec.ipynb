# %%
import os
import torch
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, cohen_kappa_score, matthews_corrcoef
import pandas as pd
import time
from sklearn import datasets
from sklearn.datasets import load_wine
from sklearn.utils import shuffle
from copy import deepcopy

# %%
'''
     ==================
       some functions
     ==================
'''

def evaluate_accuracy(dataloader, model):
    model.eval()
    y_true, y_pred = [], []

    with torch.no_grad():
        for data, target in dataloader:
            output = model(data)
            preds = torch.argmax(output, dim=1)
            y_true.extend(target.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())

    return (
        accuracy_score(y_true, y_pred, ) * 100,
        f1_score(y_true, y_pred, average='macro', zero_division=0) * 100,
        precision_score(y_true, y_pred, average='macro', zero_division=0) * 100,
        recall_score(y_true, y_pred, average='macro', zero_division=0) * 100,
        cohen_kappa_score(y_true, y_pred),
        matthews_corrcoef(y_true, y_pred),
        y_true, 
        y_pred
        )
        
def cost_fidelity(output, target):
    return torch.mean((1 - output[range(len(target)), target]) ** 2)

# %%
'''
      ==================
         1 qutrit QNN
      ==================
'''

# class QNN_0_Sum(nn.Module):

#     def __init__(self, num_layers, num_features, num_params, init_weights=None):
#         super(QNN_0_Sum, self).__init__()

#         self.num_layers = num_layers
#         self.num_features = num_features
#         self.num_params = num_params

#         # Qutrit basis
#         q0 = torch.tensor([[1], [0], [0]], dtype=torch.complex64)
#         q1 = torch.tensor([[0], [1], [0]], dtype=torch.complex64)
#         q2 = torch.tensor([[0], [0], [1]], dtype=torch.complex64)
#         self.register_buffer("q0", q0)
#         self.register_buffer("q1", q1)
#         self.register_buffer("q2", q2)

#         # Outer product helper
#         gm = lambda A, B: torch.kron(A, B.T)

#         # Gell-Mann generators
#         # Gell-Mann generators
#         gm1 = (gm(q0, q1) + gm(q1, q0)).to(torch.complex64)
#         gm2 = (-1j * (gm(q0, q1) - gm(q1, q0))).to(torch.complex64)
#         gm3 = (gm(q0, q0) - gm(q1, q1)).to(torch.complex64)
#         gm4 = (gm(q0, q2) + gm(q2, q0)).to(torch.complex64)
#         gm5 = (-1j * (gm(q0, q2) - gm(q2, q0))).to(torch.complex64)
#         gm6 = (gm(q1, q2) + gm(q2, q1)).to(torch.complex64)
#         gm7 = (-1j * (gm(q1, q2) - gm(q2, q1))).to(torch.complex64)
#         gm8 = (1 / torch.sqrt(torch.tensor(3., dtype=torch.float32)) * (gm(q0, q0) + gm(q1, q1) - 2 * gm(q2, q2))).to(torch.complex64)
            
#         Sz12 = (gm(q1, q1) - gm(q2, q2)).to(torch.complex64)
#         Sz02 = (gm(q0, q0) - gm(q2, q2)).to(torch.complex64)
        
        
#         # Configurations
        
#         #C30
#         generators12345678 = [gm1,
#                               gm2,
#                               gm3, 
#                               gm4, 
#                               gm5,
#                               gm6,
#                               gm7,
#                               gm8]
        
#         #C31
#         generators123 = [gm1,
#                          gm2, 
#                          gm3]
        
#         generators456 = [gm4,
#                          gm5, 
#                          gm6]
        
#         #C32     
#         generatorsYYY = [gm2,  # Sy_01
#                          gm5,  # Sy_02
#                          gm7]  # Sy_12
                     


#         #C32           
#         generatorsYYYZ = [gm2,  # Sy_01
#                           gm5,  # Sy_02
#                           gm7,  # Sy_12
#                           gm3]  # Sz_01
        
    
        
#         generators_enc = generatorsYYY
        
#         generators_var = generatorsYYY
            
        
#         self.register_buffer("gens_enc", torch.stack(generators_enc[:self.num_features]))  # [F, 3, 3]
#         self.register_buffer("gens_var", torch.stack(generators_var[:self.num_params]))  # [F, 3, 3]
        
#         # Label projectors
#         self.register_buffer("label_ops", torch.stack([gm(q, q) for q in [q0, q1, q2]]))


#         # Per-layer weights with num_features components
#         self.weights = nn.ParameterList([
#             nn.Parameter(init_weights[i] if init_weights else torch.rand(self.num_params) * 2 - 1)
#             for i in range(num_layers)
#         ])

#     def forward(self, batch):
#         """
#         batch: Tensor of shape [B, num_features]
#         """
#         B = batch.shape[0]

#         # Initial qutrit state expanded for batch: [B, 3, 1]
#         state = self.q0.expand(B, -1, -1).clone()  # [B, 3, 1]
        
#         one_j = torch.tensor(1j, dtype=torch.complex64)

#         for i in range(self.num_layers):
#             # Encoding
#             gen = self.gens_enc.unsqueeze(0)  # [1, F, 3, 3]
#             x = batch.unsqueeze(-1).unsqueeze(-1)  # [B, F, 1, 1]
#             encoded = (x * gen).sum(dim=1).to(torch.complex64)  # [B, 3, 3]
#             U_enc = torch.matrix_exp(one_j * encoded)
#             state = torch.matmul(U_enc, state)
            
#             # Variational
#             gen = self.gens_var.unsqueeze(0) 
#             w = self.weights[i].unsqueeze(0).expand(B, -1).unsqueeze(-1).unsqueeze(-1)
#             encoded = (w * gen).sum(dim=1).to(torch.complex64)
#             U_var = torch.matrix_exp(one_j * encoded)
#             state = torch.matmul(U_var, state)


#         # ----- Density matrix -----
#         rho = torch.matmul(state, state.conj().transpose(-2, -1))  # [B, 3, 3]
#         rho = (rho + rho.conj().transpose(-2, -1)) / 2  # Hermitian

#         # ----- Fidelities -----
#         fidelities = []
#         for op in self.label_ops:
#             op_batch = op.unsqueeze(0).expand(B, -1, -1)  # [B, 3, 3]
#             product = torch.matmul(rho, op_batch)  # [B, 3, 3]
#             eigvals, _ = torch.linalg.eig(product)
#             eigvals_real = torch.clamp(eigvals.real, min=1e-10)
#             fidelities.append(torch.sum(torch.sqrt(eigvals_real), dim=1) ** 2)

#         fstack = torch.stack(fidelities, dim=1)  # [B, 3]
#         return fstack / fstack.sum(dim=1, keepdim=True)


# General SU(N)-----------------
class QNN_0_Prod(nn.Module):
    
    def __init__(self, num_layers, num_features, num_params, init_weights=None):
        super(QNN_0_Prod, self).__init__()
        self.num_layers = num_layers
        self.num_features = num_features
        self.num_params = num_params

        # Qutrit basis
        q0 = torch.tensor([[1], [0], [0]], dtype=torch.complex64)
        q1 = torch.tensor([[0], [1], [0]], dtype=torch.complex64)
        q2 = torch.tensor([[0], [0], [1]], dtype=torch.complex64)
        self.register_buffer("q0", q0)
        self.register_buffer("q1", q1)
        self.register_buffer("q2", q2)

        # Outer product helper
        gm = lambda A, B: torch.kron(A, B.T)
        
        # Gell-Mann generators
        gm1 = (gm(q0, q1) + gm(q1, q0)).to(torch.complex64)
        gm2 = (-1j * (gm(q0, q1) - gm(q1, q0))).to(torch.complex64)
        gm3 = (gm(q0, q0) - gm(q1, q1)).to(torch.complex64)
        gm4 = (gm(q0, q2) + gm(q2, q0)).to(torch.complex64)
        gm5 = (-1j * (gm(q0, q2) - gm(q2, q0))).to(torch.complex64)
        gm6 = (gm(q1, q2) + gm(q2, q1)).to(torch.complex64)
        gm7 = (-1j * (gm(q1, q2) - gm(q2, q1))).to(torch.complex64)
        gm8 = (1 / torch.sqrt(torch.tensor(3., dtype=torch.float32)) * (gm(q0, q0) + gm(q1, q1) - 2 * gm(q2, q2))).to(torch.complex64)
            
        Sz12 = (gm(q1, q1) - gm(q2, q2)).to(torch.complex64)
        Sz02 = (gm(q0, q0) - gm(q2, q2)).to(torch.complex64)
        
        # Configurations
        
        # C32
        generatorsYYY = [gm2,    # RY_01
                         gm5,    # RY_02
                         gm7]    # RY_12
        
        generatorsZZZ = [gm3,    # RZ_01
                         Sz02,   # RZ_02
                         Sz12]   # RZ_12
        
        generatorsYYYZ = [gm2,   # RY_01
                          gm5,   # RY_02
                          gm7,   # RY_12
                          gm3]   # RZ_01
        
        generatorYZYZ = [gm2,    # RY_01
                         gm3,    # RZ_01
                         gm7,    # RY_12
                         Sz12]   # RZ_12

        generators_generalU = [gm8,
                               gm3,
                               gm2,
                               gm3,
                               gm5,
                               gm3,
                               gm2,
                               gm3]

        generators_enc = generators_generalU
        generators_var = generators_generalU
     
        # Subset para codificación, todos para la parte variacional
        self.register_buffer("gens_enc", torch.stack(generators_enc[:self.num_features]))  # [F, 3, 3]
        self.register_buffer("gens_var", torch.stack(generators_var[:self.num_params]))    # [P, 3, 3]
        
        # Label projectors: |0><0|, |1><1|, |2><2|
        self.register_buffer("label_ops", torch.stack([gm(q, q) for q in [q0, q1, q2]]))

        # initial state
        self.q0 = q0

        # parameters per layer
        self.weights = nn.ParameterList([
            nn.Parameter(init_weights[i] if init_weights else torch.rand(6)*2 - 1)
            for i in range(num_layers)
        ])

    def forward(self, batch):
        batch_size = batch.shape[0]
        batch_c = batch.to(torch.cfloat)

        state = self.q0.expand(batch_size, -1, -1).clone()

        for i in range(self.num_layers):
            # Encoding
            for j in range(self.num_features):
                G = self.gens_enc[j]
                x = batch_c[:, j].view(-1, 1, 1)
                U = torch.matrix_exp(1j * x * G)
                state = torch.bmm(U, state)

            # Variational
            for j, G in enumerate(self.gens_var):
                theta = self.weights[i][j]
                U = torch.matrix_exp(1j * theta * G)
                state = torch.matmul(U, state)

        # density matrix
        rho = state @ state.conj().transpose(-2, -1)
        rho = (rho + rho.conj().transpose(-2, -1)) / 2  # ensure Hermitian

        # fidelity
        fidelities = []
        for op in self.label_ops:
            op_batch = op.unsqueeze(0).expand(batch_size, -1, -1)
            product = rho @ op_batch
            eigvals, _ = torch.linalg.eig(product)
            eigvals_real = torch.clamp(eigvals.real, min=1e-10)
            fidelities.append(torch.sum(torch.sqrt(eigvals_real), dim=1) ** 2)

        fstack = torch.stack(fidelities, dim=1)
        return fstack / fstack.sum(dim=1, keepdim=True)

# %%
'''
      ==================
            data
      ==================
'''

# create MinMaxScaler object
scaler = MinMaxScaler()


class CustomDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]



def load_dataset(n_components):

    # dataset
    wine = load_wine()

    # features
    X_data = wine.data
    X_data = scaler.fit_transform(X_data)

    # labels
    y_data = wine.target

    pca = PCA(n_components=n_components)

    x_data = pca.fit_transform(X_data)

    x_data, y_data = shuffle(x_data, y_data, random_state=42)

    return x_data, y_data, pca.explained_variance_ratio_.sum()

# %%
'''
     =====================================
                training (prod)
     =====================================
'''

def eval_loss_full(dataloader, model):
    model.eval()
    tot = 0.0
    n = 0
    with torch.no_grad():
        for data, target in dataloader:
            out = model(data)
            l = cost_fidelity(out, target)
            bs = data.size(0)
            tot += float(l) * bs
            n += bs
    return tot / max(n, 1)

# Configs
N_TRIALS     = 4000
EPOCHS       = 200
BATCH_SIZE   = 32
LAYERS       = 6
LR           = 0.006
SAVE_EVERY   = 100
NUM_FEATURES = 5
NUM_PARAMS   = 8

BASE_SAVE_DIR = "/Users/ccristiano/Documents/Codigos/QML/Wine/qutrit/data/SequentialTraining"
os.makedirs(BASE_SAVE_DIR, exist_ok=True)


# Tracking (Option 1)
results_all = []
best_params_by_param = {}
best_loss = float("inf")
best_params = None
best_train_acc = 0.0
best_init_weights = None
best_training_time = None
best_so_far_rows = [] 
log_progress = []
chunk = 1

# Tracking (Option 2)
# import ast
# results_all = []
# best_params_by_param = {}
# metrics_file = f"{BASE_SAVE_DIR}/modelo_optimo_NUM_FEATURES_{NUM_FEATURES}_NUM_PARAMS_{NUM_PARAMS}_metrics.csv"
# df_prev = pd.read_csv(metrics_file)
# best_loss = float(df_prev["Loss"].iloc[0])
# best_train_acc = float(df_prev["TrainAcc"].iloc[0])
# best_init_weights = ast.literal_eval(df_prev["InitWeights"].iloc[0])
# best_init_weights = [torch.tensor(w, dtype=torch.float32) for w in best_init_weights]
# best_params = torch.load(f"{BASE_SAVE_DIR}/params_NUM_FEATURES_{NUM_FEATURES}_NUM_PARAMS_{NUM_PARAMS}.pt")
# print(f"📂 Cargado mejor modelo anterior: loss={best_loss:.6f}, acc={best_train_acc:.2f}%")
# best_training_time = None
# best_so_far_rows = [] 
# log_progress = []
# chunk = 1

# Dataset
X, y, exp_var = load_dataset(NUM_FEATURES)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)
train_dl = DataLoader(CustomDataset(X_train, y_train), batch_size=BATCH_SIZE, shuffle=True)
test_dl  = DataLoader(CustomDataset(X_test,  y_test),  batch_size=BATCH_SIZE, shuffle=False)
print(f"Explained variance is {exp_var}")

for trial in range(1, N_TRIALS + 1):
    print(f"\n🎯 Trial {trial}/{N_TRIALS}...")

    time_start_trial = time.time()

    # Inicialization
    init_weights = [torch.rand(NUM_PARAMS) * 2 - 1 for _ in range(LAYERS)]
    model = QNN_0_Prod(LAYERS, NUM_FEATURES, NUM_PARAMS, init_weights)
    optimizer = torch.optim.Adam(model.parameters(), lr=LR)

    # (Opcional)
    for p in model.parameters():
        p.data.clamp_(-2 * np.pi, 2 * np.pi)

    # Training
    for epoch in range(EPOCHS):
        model.train()
        for data, target in train_dl:
            optimizer.zero_grad()
            out = model(data)
            loss = cost_fidelity(out, target)   
            loss.backward()
            optimizer.step()

    # Loss over the whole dataset
    final_loss = eval_loss_full(train_dl, model)

    # Train accuracy
    train_acc, *_ = evaluate_accuracy(train_dl, model)

    # Trial training time
    time_end_trial = time.time() - time_start_trial

    # Save best trial (by loss)
    if final_loss < best_loss:
        best_loss = final_loss
        best_params = deepcopy(model.state_dict())
        best_train_acc = train_acc
        best_init_weights = deepcopy(init_weights)
        best_training_time = time_end_trial
        
    # Register
    best_so_far_rows.append({
        "Trial": trial,
        "BestLossSoFar": best_loss,
        "BestTrainAccSoFar": best_train_acc
    })

    print(f"   🔍 Final Train Loss (avg): {final_loss:.6f} | "
          f"Best so far: {best_loss:.6f} | Train Acc: {train_acc:.2f}% | "
          f"Time: {time_end_trial:.2f}s")


    # Progress log
    log_progress.append({
        "NUM_FEATURES": NUM_FEATURES,
        "Trial": trial,
        "BestTrainLoss": best_loss,
        "BestTrainAcc": best_train_acc,
        "Time": time_end_trial
    })

    # Save data 
    if trial % SAVE_EVERY == 0:
        df_log = pd.DataFrame(log_progress)
        file_name = f"{BASE_SAVE_DIR}/train_progress_NUMFEATURES_{NUM_FEATURES}_NUM_PARAMS_{NUM_PARAMS}_LAYERS_{LAYERS}_{chunk}.csv"
        df_log.to_csv(file_name, index=False)

        # Reiniciar logs del bloque
        log_progress = []
        chunk += 1

# Evaluate in test dataset
model = QNN_0_Prod(LAYERS, NUM_FEATURES, NUM_PARAMS, [w.detach().clone() for w in best_init_weights])
model.load_state_dict(best_params)
test_acc, test_f1, test_prec, test_rec, test_kappa, test_matthews, _, _ = evaluate_accuracy(test_dl, model)

# Save model and metrics
torch.save(best_params, f"{BASE_SAVE_DIR}/params_NUM_FEATURES_{NUM_FEATURES}_NUM_PARAMS_{NUM_PARAMS}_LAYERS_{LAYERS}.pt")

df_test_metrics = pd.DataFrame([{
    "NUM_FEATURES": NUM_FEATURES,
    "NUM_PARAMS": NUM_PARAMS,
    "Loss": best_loss,  
    "TrainAcc": best_train_acc,
    "TestAcc": test_acc,
    "TestF1": test_f1,
    "TestPrecision": test_prec,
    "TestRecall": test_rec,
    "CohenKappa": test_kappa,
    "MatthewsCorr": test_matthews,
    "InitWeights": [w.detach().cpu().numpy().tolist() for w in best_init_weights],
    "TrainingTime": best_training_time
}])

df_test_metrics.to_csv(
    f"{BASE_SAVE_DIR}/metrics_NUMFEATURES_{NUM_FEATURES}_NUM_PARAMS_{NUM_PARAMS}_LAYERS_{LAYERS}.csv",
    index=False
)

os.makedirs(BASE_SAVE_DIR, exist_ok=True)
pd.DataFrame(best_so_far_rows).to_csv(
    f"{BASE_SAVE_DIR}/best_so_far_NUMFEATURES_{NUM_FEATURES}_NUM_PARAMS_{NUM_PARAMS}_LAYERS_{LAYERS}.csv",
    index=False
)
# Out:
# Explained variance is 0.8127348585863358
#
# 🎯 Trial 1/4000...
#    🔍 Final Train Loss (avg): 0.042500 | Best so far: 0.042500 | Train Acc: 99.30% | Time: 9.89s
#
# 🎯 Trial 2/4000...
#    🔍 Final Train Loss (avg): 0.035886 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.85s
#
# 🎯 Trial 3/4000...
#    🔍 Final Train Loss (avg): 0.064310 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 9.82s
#
# 🎯 Trial 4/4000...
#    🔍 Final Train Loss (avg): 0.047581 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.79s
#
# 🎯 Trial 5/4000...
#    🔍 Final Train Loss (avg): 0.048887 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.77s
#
# 🎯 Trial 6/4000...
#    🔍 Final Train Loss (avg): 0.059546 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.77s
#
# 🎯 Trial 7/4000...
#    🔍 Final Train Loss (avg): 0.052627 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.76s
#
# 🎯 Trial 8/4000...
#    🔍 Final Train Loss (avg): 0.049873 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.77s
#
# 🎯 Trial 9/4000...
#    🔍 Final Train Loss (avg): 0.047778 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.81s
#
# 🎯 Trial 10/4000...
#    🔍 Final Train Loss (avg): 0.050848 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.76s
#
# 🎯 Trial 11/4000...
#    🔍 Final Train Loss (avg): 0.061858 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 9.79s
#
# 🎯 Trial 12/4000...
#    🔍 Final Train Loss (avg): 0.046159 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.73s
#
# 🎯 Trial 13/4000...
#    🔍 Final Train Loss (avg): 0.043232 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.79s
#
# 🎯 Trial 14/4000...
#    🔍 Final Train Loss (avg): 0.050313 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.75s
#
# 🎯 Trial 15/4000...
#    🔍 Final Train Loss (avg): 0.041279 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.80s
#
# 🎯 Trial 16/4000...
#    🔍 Final Train Loss (avg): 0.045810 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.80s
#
# 🎯 Trial 17/4000...
#    🔍 Final Train Loss (avg): 0.041912 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.69s
#
# 🎯 Trial 18/4000...
#    🔍 Final Train Loss (avg): 0.047435 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.72s
#
# 🎯 Trial 19/4000...
#    🔍 Final Train Loss (avg): 0.043888 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.76s
#
# 🎯 Trial 20/4000...
#    🔍 Final Train Loss (avg): 0.043835 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.85s
#
# 🎯 Trial 21/4000...
#    🔍 Final Train Loss (avg): 0.051868 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.84s
#
# 🎯 Trial 22/4000...
#    🔍 Final Train Loss (avg): 0.048716 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.81s
#
# 🎯 Trial 23/4000...
#    🔍 Final Train Loss (avg): 0.053708 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.80s
#
# 🎯 Trial 24/4000...
#    🔍 Final Train Loss (avg): 0.042210 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.80s
#
# 🎯 Trial 25/4000...
#    🔍 Final Train Loss (avg): 0.051883 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.96s
#
# 🎯 Trial 26/4000...
#    🔍 Final Train Loss (avg): 0.059312 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.78s
#
# 🎯 Trial 27/4000...
#    🔍 Final Train Loss (avg): 0.041704 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.78s
#
# 🎯 Trial 28/4000...
#    🔍 Final Train Loss (avg): 0.043842 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.89s
#
# 🎯 Trial 29/4000...
#    🔍 Final Train Loss (avg): 0.049340 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.76s
#
# 🎯 Trial 30/4000...
#    🔍 Final Train Loss (avg): 0.046078 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.78s
#
# 🎯 Trial 31/4000...
#    🔍 Final Train Loss (avg): 0.046409 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.77s
#
# 🎯 Trial 32/4000...
#    🔍 Final Train Loss (avg): 0.061672 | Best so far: 0.035886 | Train Acc: 94.37% | Time: 9.78s
#
# 🎯 Trial 33/4000...
#    🔍 Final Train Loss (avg): 0.060154 | Best so far: 0.035886 | Train Acc: 94.37% | Time: 9.75s
#
# 🎯 Trial 34/4000...
#    🔍 Final Train Loss (avg): 0.050860 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.87s
#
# 🎯 Trial 35/4000...
#    🔍 Final Train Loss (avg): 0.054096 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 9.74s
#
# 🎯 Trial 36/4000...
#    🔍 Final Train Loss (avg): 0.043763 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.83s
#
# 🎯 Trial 37/4000...
#    🔍 Final Train Loss (avg): 0.046378 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.81s
#
# 🎯 Trial 38/4000...
#    🔍 Final Train Loss (avg): 0.048759 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.85s
#
# 🎯 Trial 39/4000...
#    🔍 Final Train Loss (avg): 0.069642 | Best so far: 0.035886 | Train Acc: 95.07% | Time: 10.09s
#
# 🎯 Trial 40/4000...
#    🔍 Final Train Loss (avg): 0.046818 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.78s
#
# 🎯 Trial 41/4000...
#    🔍 Final Train Loss (avg): 0.041868 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.78s
#
# 🎯 Trial 42/4000...
#    🔍 Final Train Loss (avg): 0.059910 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.78s
#
# 🎯 Trial 43/4000...
#    🔍 Final Train Loss (avg): 0.043457 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.78s
#
# 🎯 Trial 44/4000...
#    🔍 Final Train Loss (avg): 0.044045 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.78s
#
# 🎯 Trial 45/4000...
#    🔍 Final Train Loss (avg): 0.054603 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.82s
#
# 🎯 Trial 46/4000...
#    🔍 Final Train Loss (avg): 0.039864 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.84s
#
# 🎯 Trial 47/4000...
#    🔍 Final Train Loss (avg): 0.053560 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.80s
#
# 🎯 Trial 48/4000...
#    🔍 Final Train Loss (avg): 0.041104 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.76s
#
# 🎯 Trial 49/4000...
#    🔍 Final Train Loss (avg): 0.052080 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.80s
#
# 🎯 Trial 50/4000...
#    🔍 Final Train Loss (avg): 0.048295 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 9.76s
#
# 🎯 Trial 51/4000...
#    🔍 Final Train Loss (avg): 0.036181 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.81s
#
# 🎯 Trial 52/4000...
#    🔍 Final Train Loss (avg): 0.059642 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.73s
#
# 🎯 Trial 53/4000...
#    🔍 Final Train Loss (avg): 0.044966 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.79s
#
# 🎯 Trial 54/4000...
#    🔍 Final Train Loss (avg): 0.055703 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.82s
#
# 🎯 Trial 55/4000...
#    🔍 Final Train Loss (avg): 0.055953 | Best so far: 0.035886 | Train Acc: 95.07% | Time: 9.83s
#
# 🎯 Trial 56/4000...
#    🔍 Final Train Loss (avg): 0.042575 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.77s
#
# 🎯 Trial 57/4000...
#    🔍 Final Train Loss (avg): 0.049786 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.77s
#
# 🎯 Trial 58/4000...
#    🔍 Final Train Loss (avg): 0.043902 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.81s
#
# 🎯 Trial 59/4000...
#    🔍 Final Train Loss (avg): 0.044352 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.78s
#
# 🎯 Trial 60/4000...
#    🔍 Final Train Loss (avg): 0.047801 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.81s
#
# 🎯 Trial 61/4000...
#    🔍 Final Train Loss (avg): 0.053927 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.78s
#
# 🎯 Trial 62/4000...
#    🔍 Final Train Loss (avg): 0.047663 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.81s
#
# 🎯 Trial 63/4000...
#    🔍 Final Train Loss (avg): 0.045065 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.80s
#
# 🎯 Trial 64/4000...
#    🔍 Final Train Loss (avg): 0.045389 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.77s
#
# 🎯 Trial 65/4000...
#    🔍 Final Train Loss (avg): 0.052174 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.81s
#
# 🎯 Trial 66/4000...
#    🔍 Final Train Loss (avg): 0.066880 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.82s
#
# 🎯 Trial 67/4000...
#    🔍 Final Train Loss (avg): 0.050292 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.75s
#
# 🎯 Trial 68/4000...
#    🔍 Final Train Loss (avg): 0.060737 | Best so far: 0.035886 | Train Acc: 95.07% | Time: 9.76s
#
# 🎯 Trial 69/4000...
#    🔍 Final Train Loss (avg): 0.047729 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.77s
#
# 🎯 Trial 70/4000...
#    🔍 Final Train Loss (avg): 0.050692 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.72s
#
# 🎯 Trial 71/4000...
#    🔍 Final Train Loss (avg): 0.059050 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 9.75s
#
# 🎯 Trial 72/4000...
#    🔍 Final Train Loss (avg): 0.053225 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.91s
#
# 🎯 Trial 73/4000...
#    🔍 Final Train Loss (avg): 0.054816 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.75s
#
# 🎯 Trial 74/4000...
#    🔍 Final Train Loss (avg): 0.048165 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.75s
#
# 🎯 Trial 75/4000...
#    🔍 Final Train Loss (avg): 0.043376 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.77s
#
# 🎯 Trial 76/4000...
#    🔍 Final Train Loss (avg): 0.043432 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.77s
#
# 🎯 Trial 77/4000...
#    🔍 Final Train Loss (avg): 0.051369 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.79s
#
# 🎯 Trial 78/4000...
#    🔍 Final Train Loss (avg): 0.052545 | Best so far: 0.035886 | Train Acc: 95.07% | Time: 9.79s
#
# 🎯 Trial 79/4000...
#    🔍 Final Train Loss (avg): 0.046118 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.81s
#
# 🎯 Trial 80/4000...
#    🔍 Final Train Loss (avg): 0.054271 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.77s
#
# 🎯 Trial 81/4000...
#    🔍 Final Train Loss (avg): 0.041193 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.83s
#
# 🎯 Trial 82/4000...
#    🔍 Final Train Loss (avg): 0.038810 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.73s
#
# 🎯 Trial 83/4000...
#    🔍 Final Train Loss (avg): 0.048330 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.72s
#
# 🎯 Trial 84/4000...
#    🔍 Final Train Loss (avg): 0.048993 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.77s
#
# 🎯 Trial 85/4000...
#    🔍 Final Train Loss (avg): 0.042402 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.81s
#
# 🎯 Trial 86/4000...
#    🔍 Final Train Loss (avg): 0.038341 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.73s
#
# 🎯 Trial 87/4000...
#    🔍 Final Train Loss (avg): 0.057748 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.86s
#
# 🎯 Trial 88/4000...
#    🔍 Final Train Loss (avg): 0.054437 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.75s
#
# 🎯 Trial 89/4000...
#    🔍 Final Train Loss (avg): 0.046555 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.81s
#
# 🎯 Trial 90/4000...
#    🔍 Final Train Loss (avg): 0.042958 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.93s
#
# 🎯 Trial 91/4000...
#    🔍 Final Train Loss (avg): 0.061407 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.81s
#
# 🎯 Trial 92/4000...
#    🔍 Final Train Loss (avg): 0.052198 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.79s
#
# 🎯 Trial 93/4000...
#    🔍 Final Train Loss (avg): 0.040321 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.73s
#
# 🎯 Trial 94/4000...
#    🔍 Final Train Loss (avg): 0.050945 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.81s
#
# 🎯 Trial 95/4000...
#    🔍 Final Train Loss (avg): 0.041421 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.78s
#
# 🎯 Trial 96/4000...
#    🔍 Final Train Loss (avg): 0.059784 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.83s
#
# 🎯 Trial 97/4000...
#    🔍 Final Train Loss (avg): 0.036235 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.81s
#
# 🎯 Trial 98/4000...
#    🔍 Final Train Loss (avg): 0.054903 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.75s
#
# 🎯 Trial 99/4000...
#    🔍 Final Train Loss (avg): 0.052227 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.79s
#
# 🎯 Trial 100/4000...
#    🔍 Final Train Loss (avg): 0.052860 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.79s
#
# 🎯 Trial 101/4000...
#    🔍 Final Train Loss (avg): 0.040493 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.77s
#
# 🎯 Trial 102/4000...
#    🔍 Final Train Loss (avg): 0.054383 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.76s
#
# 🎯 Trial 103/4000...
#    🔍 Final Train Loss (avg): 0.056559 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.76s
#
# 🎯 Trial 104/4000...
#    🔍 Final Train Loss (avg): 0.045300 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.82s
#
# 🎯 Trial 105/4000...
#    🔍 Final Train Loss (avg): 0.043379 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.78s
#
# 🎯 Trial 106/4000...
#    🔍 Final Train Loss (avg): 0.059852 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.81s
#
# 🎯 Trial 107/4000...
#    🔍 Final Train Loss (avg): 0.054398 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.72s
#
# 🎯 Trial 108/4000...
#    🔍 Final Train Loss (avg): 0.047100 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.78s
#
# 🎯 Trial 109/4000...
#    🔍 Final Train Loss (avg): 0.048368 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.80s
#
# 🎯 Trial 110/4000...
#    🔍 Final Train Loss (avg): 0.049511 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.76s
#
# 🎯 Trial 111/4000...
#    🔍 Final Train Loss (avg): 0.050250 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.85s
#
# 🎯 Trial 112/4000...
#    🔍 Final Train Loss (avg): 0.049408 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.84s
#
# 🎯 Trial 113/4000...
#    🔍 Final Train Loss (avg): 0.048923 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.77s
#
# 🎯 Trial 114/4000...
#    🔍 Final Train Loss (avg): 0.054416 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.75s
#
# 🎯 Trial 115/4000...
#    🔍 Final Train Loss (avg): 0.045696 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.74s
#
# 🎯 Trial 116/4000...
#    🔍 Final Train Loss (avg): 0.053156 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.78s
#
# 🎯 Trial 117/4000...
#    🔍 Final Train Loss (avg): 0.047337 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 10.05s
#
# 🎯 Trial 118/4000...
#    🔍 Final Train Loss (avg): 0.051346 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.78s
#
# 🎯 Trial 119/4000...
#    🔍 Final Train Loss (avg): 0.044421 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.78s
#
# 🎯 Trial 120/4000...
#    🔍 Final Train Loss (avg): 0.046419 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.84s
#
# 🎯 Trial 121/4000...
#    🔍 Final Train Loss (avg): 0.063221 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.84s
#
# 🎯 Trial 122/4000...
#    🔍 Final Train Loss (avg): 0.064340 | Best so far: 0.035886 | Train Acc: 95.07% | Time: 9.78s
#
# 🎯 Trial 123/4000...
#    🔍 Final Train Loss (avg): 0.041468 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.75s
#
# 🎯 Trial 124/4000...
#    🔍 Final Train Loss (avg): 0.044334 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.77s
#
# 🎯 Trial 125/4000...
#    🔍 Final Train Loss (avg): 0.046873 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.80s
#
# 🎯 Trial 126/4000...
#    🔍 Final Train Loss (avg): 0.041949 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.76s
#
# 🎯 Trial 127/4000...
#    🔍 Final Train Loss (avg): 0.054581 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.76s
#
# 🎯 Trial 128/4000...
#    🔍 Final Train Loss (avg): 0.052112 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.84s
#
# 🎯 Trial 129/4000...
#    🔍 Final Train Loss (avg): 0.070588 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.80s
#
# 🎯 Trial 130/4000...
#    🔍 Final Train Loss (avg): 0.042683 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.84s
#
# 🎯 Trial 131/4000...
#    🔍 Final Train Loss (avg): 0.039858 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.74s
#
# 🎯 Trial 132/4000...
#    🔍 Final Train Loss (avg): 0.038986 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.77s
#
# 🎯 Trial 133/4000...
#    🔍 Final Train Loss (avg): 0.053165 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 9.79s
#
# 🎯 Trial 134/4000...
#    🔍 Final Train Loss (avg): 0.049528 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 9.78s
#
# 🎯 Trial 135/4000...
#    🔍 Final Train Loss (avg): 0.042215 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.81s
#
# 🎯 Trial 136/4000...
#    🔍 Final Train Loss (avg): 0.054686 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.92s
#
# 🎯 Trial 137/4000...
#    🔍 Final Train Loss (avg): 0.058103 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.78s
#
# 🎯 Trial 138/4000...
#    🔍 Final Train Loss (avg): 0.052960 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.75s
#
# 🎯 Trial 139/4000...
#    🔍 Final Train Loss (avg): 0.042702 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.79s
#
# 🎯 Trial 140/4000...
#    🔍 Final Train Loss (avg): 0.051196 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.72s
#
# 🎯 Trial 141/4000...
#    🔍 Final Train Loss (avg): 0.043997 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.72s
#
# 🎯 Trial 142/4000...
#    🔍 Final Train Loss (avg): 0.049165 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.73s
#
# 🎯 Trial 143/4000...
#    🔍 Final Train Loss (avg): 0.053651 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.78s
#
# 🎯 Trial 144/4000...
#    🔍 Final Train Loss (avg): 0.050343 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.71s
#
# 🎯 Trial 145/4000...
#    🔍 Final Train Loss (avg): 0.047992 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.78s
#
# 🎯 Trial 146/4000...
#    🔍 Final Train Loss (avg): 0.045114 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.77s
#
# 🎯 Trial 147/4000...
#    🔍 Final Train Loss (avg): 0.051353 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.81s
#
# 🎯 Trial 148/4000...
#    🔍 Final Train Loss (avg): 0.052237 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.75s
#
# 🎯 Trial 149/4000...
#    🔍 Final Train Loss (avg): 0.040744 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.69s
#
# 🎯 Trial 150/4000...
#    🔍 Final Train Loss (avg): 0.049354 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.78s
#
# 🎯 Trial 151/4000...
#    🔍 Final Train Loss (avg): 0.054387 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.75s
#
# 🎯 Trial 152/4000...
#    🔍 Final Train Loss (avg): 0.051591 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.74s
#
# 🎯 Trial 153/4000...
#    🔍 Final Train Loss (avg): 0.053557 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.71s
#
# 🎯 Trial 154/4000...
#    🔍 Final Train Loss (avg): 0.051870 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.80s
#
# 🎯 Trial 155/4000...
#    🔍 Final Train Loss (avg): 0.043046 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.81s
#
# 🎯 Trial 156/4000...
#    🔍 Final Train Loss (avg): 0.043759 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.69s
#
# 🎯 Trial 157/4000...
#    🔍 Final Train Loss (avg): 0.042402 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.74s
#
# 🎯 Trial 158/4000...
#    🔍 Final Train Loss (avg): 0.059824 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.80s
#
# 🎯 Trial 159/4000...
#    🔍 Final Train Loss (avg): 0.044457 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.74s
#
# 🎯 Trial 160/4000...
#    🔍 Final Train Loss (avg): 0.044034 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.80s
#
# 🎯 Trial 161/4000...
#    🔍 Final Train Loss (avg): 0.047896 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.82s
#
# 🎯 Trial 162/4000...
#    🔍 Final Train Loss (avg): 0.062303 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.77s
#
# 🎯 Trial 163/4000...
#    🔍 Final Train Loss (avg): 0.049319 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.77s
#
# 🎯 Trial 164/4000...
#    🔍 Final Train Loss (avg): 0.045474 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.71s
#
# 🎯 Trial 165/4000...
#    🔍 Final Train Loss (avg): 0.054534 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.72s
#
# 🎯 Trial 166/4000...
#    🔍 Final Train Loss (avg): 0.043685 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.79s
#
# 🎯 Trial 167/4000...
#    🔍 Final Train Loss (avg): 0.050914 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.74s
#
# 🎯 Trial 168/4000...
#    🔍 Final Train Loss (avg): 0.060577 | Best so far: 0.035886 | Train Acc: 95.07% | Time: 9.77s
#
# 🎯 Trial 169/4000...
#    🔍 Final Train Loss (avg): 0.061328 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.77s
#
# 🎯 Trial 170/4000...
#    🔍 Final Train Loss (avg): 0.048763 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.76s
#
# 🎯 Trial 171/4000...
#    🔍 Final Train Loss (avg): 0.048533 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.78s
#
# 🎯 Trial 172/4000...
#    🔍 Final Train Loss (avg): 0.050212 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.73s
#
# 🎯 Trial 173/4000...
#    🔍 Final Train Loss (avg): 0.038214 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.72s
#
# 🎯 Trial 174/4000...
#    🔍 Final Train Loss (avg): 0.060782 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.80s
#
# 🎯 Trial 175/4000...
#    🔍 Final Train Loss (avg): 0.046903 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.72s
#
# 🎯 Trial 176/4000...
#    🔍 Final Train Loss (avg): 0.053946 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 10.04s
#
# 🎯 Trial 177/4000...
#    🔍 Final Train Loss (avg): 0.039788 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.72s
#
# 🎯 Trial 178/4000...
#    🔍 Final Train Loss (avg): 0.051444 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.72s
#
# 🎯 Trial 179/4000...
#    🔍 Final Train Loss (avg): 0.048201 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.76s
#
# 🎯 Trial 180/4000...
#    🔍 Final Train Loss (avg): 0.042078 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.73s
#
# 🎯 Trial 181/4000...
#    🔍 Final Train Loss (avg): 0.049113 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.79s
#
# 🎯 Trial 182/4000...
#    🔍 Final Train Loss (avg): 0.041176 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.79s
#
# 🎯 Trial 183/4000...
#    🔍 Final Train Loss (avg): 0.049616 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.72s
#
# 🎯 Trial 184/4000...
#    🔍 Final Train Loss (avg): 0.051144 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.69s
#
# 🎯 Trial 185/4000...
#    🔍 Final Train Loss (avg): 0.050979 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.88s
#
# 🎯 Trial 186/4000...
#    🔍 Final Train Loss (avg): 0.053687 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.75s
#
# 🎯 Trial 187/4000...
#    🔍 Final Train Loss (avg): 0.042765 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.68s
#
# 🎯 Trial 188/4000...
#    🔍 Final Train Loss (avg): 0.086067 | Best so far: 0.035886 | Train Acc: 92.96% | Time: 9.73s
#
# 🎯 Trial 189/4000...
#    🔍 Final Train Loss (avg): 0.040143 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.70s
#
# 🎯 Trial 190/4000...
#    🔍 Final Train Loss (avg): 0.049002 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.74s
#
# 🎯 Trial 191/4000...
#    🔍 Final Train Loss (avg): 0.047616 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.80s
#
# 🎯 Trial 192/4000...
#    🔍 Final Train Loss (avg): 0.043646 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.73s
#
# 🎯 Trial 193/4000...
#    🔍 Final Train Loss (avg): 0.044352 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.74s
#
# 🎯 Trial 194/4000...
#    🔍 Final Train Loss (avg): 0.049645 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.82s
#
# 🎯 Trial 195/4000...
#    🔍 Final Train Loss (avg): 0.054553 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.75s
#
# 🎯 Trial 196/4000...
#    🔍 Final Train Loss (avg): 0.041012 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.73s
#
# 🎯 Trial 197/4000...
#    🔍 Final Train Loss (avg): 0.055375 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.73s
#
# 🎯 Trial 198/4000...
#    🔍 Final Train Loss (avg): 0.058057 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 9.84s
#
# 🎯 Trial 199/4000...
#    🔍 Final Train Loss (avg): 0.053479 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.79s
#
# 🎯 Trial 200/4000...
#    🔍 Final Train Loss (avg): 0.049051 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.79s
#
# 🎯 Trial 201/4000...
#    🔍 Final Train Loss (avg): 0.053801 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.71s
#
# 🎯 Trial 202/4000...
#    🔍 Final Train Loss (avg): 0.038450 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.73s
#
# 🎯 Trial 203/4000...
#    🔍 Final Train Loss (avg): 0.074138 | Best so far: 0.035886 | Train Acc: 92.96% | Time: 9.73s
#
# 🎯 Trial 204/4000...
#    🔍 Final Train Loss (avg): 0.064618 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.81s
#
# 🎯 Trial 205/4000...
#    🔍 Final Train Loss (avg): 0.052343 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.78s
#
# 🎯 Trial 206/4000...
#    🔍 Final Train Loss (avg): 0.059084 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.75s
#
# 🎯 Trial 207/4000...
#    🔍 Final Train Loss (avg): 0.052543 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.71s
#
# 🎯 Trial 208/4000...
#    🔍 Final Train Loss (avg): 0.065602 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.72s
#
# 🎯 Trial 209/4000...
#    🔍 Final Train Loss (avg): 0.050422 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.76s
#
# 🎯 Trial 210/4000...
#    🔍 Final Train Loss (avg): 0.060870 | Best so far: 0.035886 | Train Acc: 95.07% | Time: 9.81s
#
# 🎯 Trial 211/4000...
#    🔍 Final Train Loss (avg): 0.046868 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.78s
#
# 🎯 Trial 212/4000...
#    🔍 Final Train Loss (avg): 0.046333 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.68s
#
# 🎯 Trial 213/4000...
#    🔍 Final Train Loss (avg): 0.064418 | Best so far: 0.035886 | Train Acc: 95.07% | Time: 9.75s
#
# 🎯 Trial 214/4000...
#    🔍 Final Train Loss (avg): 0.050540 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.75s
#
# 🎯 Trial 215/4000...
#    🔍 Final Train Loss (avg): 0.039070 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.74s
#
# 🎯 Trial 216/4000...
#    🔍 Final Train Loss (avg): 0.046223 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.70s
#
# 🎯 Trial 217/4000...
#    🔍 Final Train Loss (avg): 0.042449 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.70s
#
# 🎯 Trial 218/4000...
#    🔍 Final Train Loss (avg): 0.048685 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.77s
#
# 🎯 Trial 219/4000...
#    🔍 Final Train Loss (avg): 0.052459 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.71s
#
# 🎯 Trial 220/4000...
#    🔍 Final Train Loss (avg): 0.041291 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.71s
#
# 🎯 Trial 221/4000...
#    🔍 Final Train Loss (avg): 0.039257 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.71s
#
# 🎯 Trial 222/4000...
#    🔍 Final Train Loss (avg): 0.044597 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.89s
#
# 🎯 Trial 223/4000...
#    🔍 Final Train Loss (avg): 0.038675 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.75s
#
# 🎯 Trial 224/4000...
#    🔍 Final Train Loss (avg): 0.054063 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.73s
#
# 🎯 Trial 225/4000...
#    🔍 Final Train Loss (avg): 0.056555 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 10.07s
#
# 🎯 Trial 226/4000...
#    🔍 Final Train Loss (avg): 0.044058 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.76s
#
# 🎯 Trial 227/4000...
#    🔍 Final Train Loss (avg): 0.042873 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.71s
#
# 🎯 Trial 228/4000...
#    🔍 Final Train Loss (avg): 0.049945 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.76s
#
# 🎯 Trial 229/4000...
#    🔍 Final Train Loss (avg): 0.045642 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.72s
#
# 🎯 Trial 230/4000...
#    🔍 Final Train Loss (avg): 0.040146 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.71s
#
# 🎯 Trial 231/4000...
#    🔍 Final Train Loss (avg): 0.059837 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.71s
#
# 🎯 Trial 232/4000...
#    🔍 Final Train Loss (avg): 0.051583 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.74s
#
# 🎯 Trial 233/4000...
#    🔍 Final Train Loss (avg): 0.047991 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.74s
#
# 🎯 Trial 234/4000...
#    🔍 Final Train Loss (avg): 0.044647 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.74s
#
# 🎯 Trial 235/4000...
#    🔍 Final Train Loss (avg): 0.050794 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.82s
#
# 🎯 Trial 236/4000...
#    🔍 Final Train Loss (avg): 0.051274 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.77s
#
# 🎯 Trial 237/4000...
#    🔍 Final Train Loss (avg): 0.063563 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.82s
#
# 🎯 Trial 238/4000...
#    🔍 Final Train Loss (avg): 0.057886 | Best so far: 0.035886 | Train Acc: 95.07% | Time: 9.69s
#
# 🎯 Trial 239/4000...
#    🔍 Final Train Loss (avg): 0.052326 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.83s
#
# 🎯 Trial 240/4000...
#    🔍 Final Train Loss (avg): 0.052652 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.77s
#
# 🎯 Trial 241/4000...
#    🔍 Final Train Loss (avg): 0.049318 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.80s
#
# 🎯 Trial 242/4000...
#    🔍 Final Train Loss (avg): 0.046753 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.74s
#
# 🎯 Trial 243/4000...
#    🔍 Final Train Loss (avg): 0.065784 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.70s
#
# 🎯 Trial 244/4000...
#    🔍 Final Train Loss (avg): 0.061633 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 9.74s
#
# 🎯 Trial 245/4000...
#    🔍 Final Train Loss (avg): 0.051558 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.77s
#
# 🎯 Trial 246/4000...
#    🔍 Final Train Loss (avg): 0.047558 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.77s
#
# 🎯 Trial 247/4000...
#    🔍 Final Train Loss (avg): 0.054266 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 9.78s
#
# 🎯 Trial 248/4000...
#    🔍 Final Train Loss (avg): 0.048903 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.68s
#
# 🎯 Trial 249/4000...
#    🔍 Final Train Loss (avg): 0.070310 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.71s
#
# 🎯 Trial 250/4000...
#    🔍 Final Train Loss (avg): 0.049486 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.76s
#
# 🎯 Trial 251/4000...
#    🔍 Final Train Loss (avg): 0.050827 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.72s
#
# 🎯 Trial 252/4000...
#    🔍 Final Train Loss (avg): 0.048091 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.70s
#
# 🎯 Trial 253/4000...
#    🔍 Final Train Loss (avg): 0.042195 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.71s
#
# 🎯 Trial 254/4000...
#    🔍 Final Train Loss (avg): 0.041811 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.64s
#
# 🎯 Trial 255/4000...
#    🔍 Final Train Loss (avg): 0.055460 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 9.79s
#
# 🎯 Trial 256/4000...
#    🔍 Final Train Loss (avg): 0.044296 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.69s
#
# 🎯 Trial 257/4000...
#    🔍 Final Train Loss (avg): 0.063163 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.72s
#
# 🎯 Trial 258/4000...
#    🔍 Final Train Loss (avg): 0.056962 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.71s
#
# 🎯 Trial 259/4000...
#    🔍 Final Train Loss (avg): 0.044105 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.73s
#
# 🎯 Trial 260/4000...
#    🔍 Final Train Loss (avg): 0.045012 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.79s
#
# 🎯 Trial 261/4000...
#    🔍 Final Train Loss (avg): 0.045020 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.81s
#
# 🎯 Trial 262/4000...
#    🔍 Final Train Loss (avg): 0.057757 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.78s
#
# 🎯 Trial 263/4000...
#    🔍 Final Train Loss (avg): 0.050458 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.74s
#
# 🎯 Trial 264/4000...
#    🔍 Final Train Loss (avg): 0.046657 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.69s
#
# 🎯 Trial 265/4000...
#    🔍 Final Train Loss (avg): 0.051863 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.72s
#
# 🎯 Trial 266/4000...
#    🔍 Final Train Loss (avg): 0.044610 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.79s
#
# 🎯 Trial 267/4000...
#    🔍 Final Train Loss (avg): 0.041336 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.69s
#
# 🎯 Trial 268/4000...
#    🔍 Final Train Loss (avg): 0.053591 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 10.00s
#
# 🎯 Trial 269/4000...
#    🔍 Final Train Loss (avg): 0.045455 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.74s
#
# 🎯 Trial 270/4000...
#    🔍 Final Train Loss (avg): 0.044583 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.75s
#
# 🎯 Trial 271/4000...
#    🔍 Final Train Loss (avg): 0.041088 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.72s
#
# 🎯 Trial 272/4000...
#    🔍 Final Train Loss (avg): 0.040337 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.78s
#
# 🎯 Trial 273/4000...
#    🔍 Final Train Loss (avg): 0.047724 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.74s
#
# 🎯 Trial 274/4000...
#    🔍 Final Train Loss (avg): 0.051445 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.66s
#
# 🎯 Trial 275/4000...
#    🔍 Final Train Loss (avg): 0.072545 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.76s
#
# 🎯 Trial 276/4000...
#    🔍 Final Train Loss (avg): 0.071473 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 9.71s
#
# 🎯 Trial 277/4000...
#    🔍 Final Train Loss (avg): 0.045681 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.78s
#
# 🎯 Trial 278/4000...
#    🔍 Final Train Loss (avg): 0.053947 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.75s
#
# 🎯 Trial 279/4000...
#    🔍 Final Train Loss (avg): 0.040705 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.72s
#
# 🎯 Trial 280/4000...
#    🔍 Final Train Loss (avg): 0.040284 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.77s
#
# 🎯 Trial 281/4000...
#    🔍 Final Train Loss (avg): 0.052480 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.70s
#
# 🎯 Trial 282/4000...
#    🔍 Final Train Loss (avg): 0.049542 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.79s
#
# 🎯 Trial 283/4000...
#    🔍 Final Train Loss (avg): 0.048901 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.66s
#
# 🎯 Trial 284/4000...
#    🔍 Final Train Loss (avg): 0.057412 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.87s
#
# 🎯 Trial 285/4000...
#    🔍 Final Train Loss (avg): 0.048302 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.87s
#
# 🎯 Trial 286/4000...
#    🔍 Final Train Loss (avg): 0.056582 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.75s
#
# 🎯 Trial 287/4000...
#    🔍 Final Train Loss (avg): 0.037005 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.75s
#
# 🎯 Trial 288/4000...
#    🔍 Final Train Loss (avg): 0.056154 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.69s
#
# 🎯 Trial 289/4000...
#    🔍 Final Train Loss (avg): 0.063445 | Best so far: 0.035886 | Train Acc: 95.07% | Time: 9.80s
#
# 🎯 Trial 290/4000...
#    🔍 Final Train Loss (avg): 0.044130 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.75s
#
# 🎯 Trial 291/4000...
#    🔍 Final Train Loss (avg): 0.043509 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.75s
#
# 🎯 Trial 292/4000...
#    🔍 Final Train Loss (avg): 0.042137 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.74s
#
# 🎯 Trial 293/4000...
#    🔍 Final Train Loss (avg): 0.049229 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 9.71s
#
# 🎯 Trial 294/4000...
#    🔍 Final Train Loss (avg): 0.054600 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.76s
#
# 🎯 Trial 295/4000...
#    🔍 Final Train Loss (avg): 0.057685 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 9.82s
#
# 🎯 Trial 296/4000...
#    🔍 Final Train Loss (avg): 0.046787 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.80s
#
# 🎯 Trial 297/4000...
#    🔍 Final Train Loss (avg): 0.048945 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.83s
#
# 🎯 Trial 298/4000...
#    🔍 Final Train Loss (avg): 0.046700 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.71s
#
# 🎯 Trial 299/4000...
#    🔍 Final Train Loss (avg): 0.055661 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.74s
#
# 🎯 Trial 300/4000...
#    🔍 Final Train Loss (avg): 0.049157 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.77s
#
# 🎯 Trial 301/4000...
#    🔍 Final Train Loss (avg): 0.058031 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.82s
#
# 🎯 Trial 302/4000...
#    🔍 Final Train Loss (avg): 0.048228 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.79s
#
# 🎯 Trial 303/4000...
#    🔍 Final Train Loss (avg): 0.049976 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.82s
#
# 🎯 Trial 304/4000...
#    🔍 Final Train Loss (avg): 0.056197 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.78s
#
# 🎯 Trial 305/4000...
#    🔍 Final Train Loss (avg): 0.041708 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.75s
#
# 🎯 Trial 306/4000...
#    🔍 Final Train Loss (avg): 0.040635 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.76s
#
# 🎯 Trial 307/4000...
#    🔍 Final Train Loss (avg): 0.040492 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 10.02s
#
# 🎯 Trial 308/4000...
#    🔍 Final Train Loss (avg): 0.063002 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.81s
#
# 🎯 Trial 309/4000...
#    🔍 Final Train Loss (avg): 0.046386 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.81s
#
# 🎯 Trial 310/4000...
#    🔍 Final Train Loss (avg): 0.055430 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.76s
#
# 🎯 Trial 311/4000...
#    🔍 Final Train Loss (avg): 0.057842 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.77s
#
# 🎯 Trial 312/4000...
#    🔍 Final Train Loss (avg): 0.040611 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.75s
#
# 🎯 Trial 313/4000...
#    🔍 Final Train Loss (avg): 0.057264 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.78s
#
# 🎯 Trial 314/4000...
#    🔍 Final Train Loss (avg): 0.042255 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.80s
#
# 🎯 Trial 315/4000...
#    🔍 Final Train Loss (avg): 0.043738 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.71s
#
# 🎯 Trial 316/4000...
#    🔍 Final Train Loss (avg): 0.045939 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.76s
#
# 🎯 Trial 317/4000...
#    🔍 Final Train Loss (avg): 0.047682 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.74s
#
# 🎯 Trial 318/4000...
#    🔍 Final Train Loss (avg): 0.041386 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.78s
#
# 🎯 Trial 319/4000...
#    🔍 Final Train Loss (avg): 0.043655 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.75s
#
# 🎯 Trial 320/4000...
#    🔍 Final Train Loss (avg): 0.047889 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.79s
#
# 🎯 Trial 321/4000...
#    🔍 Final Train Loss (avg): 0.066613 | Best so far: 0.035886 | Train Acc: 93.66% | Time: 9.74s
#
# 🎯 Trial 322/4000...
#    🔍 Final Train Loss (avg): 0.053453 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.74s
#
# 🎯 Trial 323/4000...
#    🔍 Final Train Loss (avg): 0.045565 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.79s
#
# 🎯 Trial 324/4000...
#    🔍 Final Train Loss (avg): 0.048571 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.83s
#
# 🎯 Trial 325/4000...
#    🔍 Final Train Loss (avg): 0.051426 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.72s
#
# 🎯 Trial 326/4000...
#    🔍 Final Train Loss (avg): 0.044325 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.73s
#
# 🎯 Trial 327/4000...
#    🔍 Final Train Loss (avg): 0.045445 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.76s
#
# 🎯 Trial 328/4000...
#    🔍 Final Train Loss (avg): 0.037830 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.76s
#
# 🎯 Trial 329/4000...
#    🔍 Final Train Loss (avg): 0.044604 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.74s
#
# 🎯 Trial 330/4000...
#    🔍 Final Train Loss (avg): 0.049359 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.80s
#
# 🎯 Trial 331/4000...
#    🔍 Final Train Loss (avg): 0.049459 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.73s
#
# 🎯 Trial 332/4000...
#    🔍 Final Train Loss (avg): 0.043204 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.73s
#
# 🎯 Trial 333/4000...
#    🔍 Final Train Loss (avg): 0.066524 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 9.81s
#
# 🎯 Trial 334/4000...
#    🔍 Final Train Loss (avg): 0.051944 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.77s
#
# 🎯 Trial 335/4000...
#    🔍 Final Train Loss (avg): 0.045864 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.73s
#
# 🎯 Trial 336/4000...
#    🔍 Final Train Loss (avg): 0.049481 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.76s
#
# 🎯 Trial 337/4000...
#    🔍 Final Train Loss (avg): 0.057491 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.73s
#
# 🎯 Trial 338/4000...
#    🔍 Final Train Loss (avg): 0.054031 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.68s
#
# 🎯 Trial 339/4000...
#    🔍 Final Train Loss (avg): 0.042755 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.82s
#
# 🎯 Trial 340/4000...
#    🔍 Final Train Loss (avg): 0.042623 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.73s
#
# 🎯 Trial 341/4000...
#    🔍 Final Train Loss (avg): 0.057061 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.73s
#
# 🎯 Trial 342/4000...
#    🔍 Final Train Loss (avg): 0.055528 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.80s
#
# 🎯 Trial 343/4000...
#    🔍 Final Train Loss (avg): 0.058689 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 10.03s
#
# 🎯 Trial 344/4000...
#    🔍 Final Train Loss (avg): 0.047883 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.75s
#
# 🎯 Trial 345/4000...
#    🔍 Final Train Loss (avg): 0.048454 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.74s
#
# 🎯 Trial 346/4000...
#    🔍 Final Train Loss (avg): 0.061372 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 9.72s
#
# 🎯 Trial 347/4000...
#    🔍 Final Train Loss (avg): 0.048620 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.80s
#
# 🎯 Trial 348/4000...
#    🔍 Final Train Loss (avg): 0.056371 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.76s
#
# 🎯 Trial 349/4000...
#    🔍 Final Train Loss (avg): 0.052368 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.74s
#
# 🎯 Trial 350/4000...
#    🔍 Final Train Loss (avg): 0.052381 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 9.77s
#
# 🎯 Trial 351/4000...
#    🔍 Final Train Loss (avg): 0.043261 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.79s
#
# 🎯 Trial 352/4000...
#    🔍 Final Train Loss (avg): 0.049312 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.75s
#
# 🎯 Trial 353/4000...
#    🔍 Final Train Loss (avg): 0.040899 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.77s
#
# 🎯 Trial 354/4000...
#    🔍 Final Train Loss (avg): 0.045615 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.80s
#
# 🎯 Trial 355/4000...
#    🔍 Final Train Loss (avg): 0.052970 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.73s
#
# 🎯 Trial 356/4000...
#    🔍 Final Train Loss (avg): 0.050641 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.79s
#
# 🎯 Trial 357/4000...
#    🔍 Final Train Loss (avg): 0.041835 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.79s
#
# 🎯 Trial 358/4000...
#    🔍 Final Train Loss (avg): 0.057188 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.74s
#
# 🎯 Trial 359/4000...
#    🔍 Final Train Loss (avg): 0.045738 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.71s
#
# 🎯 Trial 360/4000...
#    🔍 Final Train Loss (avg): 0.048921 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.88s
#
# 🎯 Trial 361/4000...
#    🔍 Final Train Loss (avg): 0.047646 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.73s
#
# 🎯 Trial 362/4000...
#    🔍 Final Train Loss (avg): 0.039091 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.72s
#
# 🎯 Trial 363/4000...
#    🔍 Final Train Loss (avg): 0.054576 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.75s
#
# 🎯 Trial 364/4000...
#    🔍 Final Train Loss (avg): 0.047689 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.75s
#
# 🎯 Trial 365/4000...
#    🔍 Final Train Loss (avg): 0.040423 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.72s
#
# 🎯 Trial 366/4000...
#    🔍 Final Train Loss (avg): 0.053352 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.81s
#
# 🎯 Trial 367/4000...
#    🔍 Final Train Loss (avg): 0.056487 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.76s
#
# 🎯 Trial 368/4000...
#    🔍 Final Train Loss (avg): 0.041418 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.70s
#
# 🎯 Trial 369/4000...
#    🔍 Final Train Loss (avg): 0.043534 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.74s
#
# 🎯 Trial 370/4000...
#    🔍 Final Train Loss (avg): 0.066757 | Best so far: 0.035886 | Train Acc: 95.07% | Time: 9.77s
#
# 🎯 Trial 371/4000...
#    🔍 Final Train Loss (avg): 0.047208 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.75s
#
# 🎯 Trial 372/4000...
#    🔍 Final Train Loss (avg): 0.047275 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.73s
#
# 🎯 Trial 373/4000...
#    🔍 Final Train Loss (avg): 0.052074 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.84s
#
# 🎯 Trial 374/4000...
#    🔍 Final Train Loss (avg): 0.058898 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 9.71s
#
# 🎯 Trial 375/4000...
#    🔍 Final Train Loss (avg): 0.061210 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.73s
#
# 🎯 Trial 376/4000...
#    🔍 Final Train Loss (avg): 0.051785 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 10.06s
#
# 🎯 Trial 377/4000...
#    🔍 Final Train Loss (avg): 0.048729 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.73s
#
# 🎯 Trial 378/4000...
#    🔍 Final Train Loss (avg): 0.044578 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.82s
#
# 🎯 Trial 379/4000...
#    🔍 Final Train Loss (avg): 0.048211 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.78s
#
# 🎯 Trial 380/4000...
#    🔍 Final Train Loss (avg): 0.039126 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.79s
#
# 🎯 Trial 381/4000...
#    🔍 Final Train Loss (avg): 0.046021 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.73s
#
# 🎯 Trial 382/4000...
#    🔍 Final Train Loss (avg): 0.051023 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.76s
#
# 🎯 Trial 383/4000...
#    🔍 Final Train Loss (avg): 0.039186 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.76s
#
# 🎯 Trial 384/4000...
#    🔍 Final Train Loss (avg): 0.046301 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.76s
#
# 🎯 Trial 385/4000...
#    🔍 Final Train Loss (avg): 0.046598 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.81s
#
# 🎯 Trial 386/4000...
#    🔍 Final Train Loss (avg): 0.050313 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.82s
#
# 🎯 Trial 387/4000...
#    🔍 Final Train Loss (avg): 0.048313 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.71s
#
# 🎯 Trial 388/4000...
#    🔍 Final Train Loss (avg): 0.047166 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.73s
#
# 🎯 Trial 389/4000...
#    🔍 Final Train Loss (avg): 0.052390 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.84s
#
# 🎯 Trial 390/4000...
#    🔍 Final Train Loss (avg): 0.057855 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.81s
#
# 🎯 Trial 391/4000...
#    🔍 Final Train Loss (avg): 0.045824 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.74s
#
# 🎯 Trial 392/4000...
#    🔍 Final Train Loss (avg): 0.064770 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.74s
#
# 🎯 Trial 393/4000...
#    🔍 Final Train Loss (avg): 0.038400 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.77s
#
# 🎯 Trial 394/4000...
#    🔍 Final Train Loss (avg): 0.036944 | Best so far: 0.035886 | Train Acc: 100.00% | Time: 9.72s
#
# 🎯 Trial 395/4000...
#    🔍 Final Train Loss (avg): 0.047885 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.73s
#
# 🎯 Trial 396/4000...
#    🔍 Final Train Loss (avg): 0.057070 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.73s
#
# 🎯 Trial 397/4000...
#    🔍 Final Train Loss (avg): 0.050410 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.74s
#
# 🎯 Trial 398/4000...
#    🔍 Final Train Loss (avg): 0.062818 | Best so far: 0.035886 | Train Acc: 96.48% | Time: 9.75s
#
# 🎯 Trial 399/4000...
#    🔍 Final Train Loss (avg): 0.053975 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.77s
#
# 🎯 Trial 400/4000...
#    🔍 Final Train Loss (avg): 0.050360 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.71s
#
# 🎯 Trial 401/4000...
#    🔍 Final Train Loss (avg): 0.043570 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.78s
#
# 🎯 Trial 402/4000...
#    🔍 Final Train Loss (avg): 0.048149 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.72s
#
# 🎯 Trial 403/4000...
#    🔍 Final Train Loss (avg): 0.055995 | Best so far: 0.035886 | Train Acc: 95.77% | Time: 9.73s
#
# 🎯 Trial 404/4000...
#    🔍 Final Train Loss (avg): 0.048340 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 9.78s
#
# 🎯 Trial 405/4000...
#    🔍 Final Train Loss (avg): 0.051691 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.70s
#
# 🎯 Trial 406/4000...
#    🔍 Final Train Loss (avg): 0.054638 | Best so far: 0.035886 | Train Acc: 99.30% | Time: 9.77s
#
# 🎯 Trial 407/4000...
#    🔍 Final Train Loss (avg): 0.048790 | Best so far: 0.035886 | Train Acc: 98.59% | Time: 10.02s
#
# 🎯 Trial 408/4000...
#    🔍 Final Train Loss (avg): 0.057612 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.71s
#
# 🎯 Trial 409/4000...
#    🔍 Final Train Loss (avg): 0.059982 | Best so far: 0.035886 | Train Acc: 97.89% | Time: 9.68s
#
# 🎯 Trial 410/4000...
#    🔍 Final Train Loss (avg): 0.048746 | Best so far: 0.035886 | Train Acc: 97.18% | Time: 9.75s
#
# 🎯 Trial 411/4000...
# ...
#
# 🎯 Trial 954/4000...
#    🔍 Final Train Loss (avg): 0.062633 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 8.75s
#
# 🎯 Trial 955/4000...
#    🔍 Final Train Loss (avg): 0.050764 | Best so far: 0.033822 | Train Acc: 95.77% | Time: 8.77s
#
# 🎯 Trial 956/4000...
#    🔍 Final Train Loss (avg): 0.044147 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 9.04s
#
# 🎯 Trial 957/4000...
#    🔍 Final Train Loss (avg): 0.047482 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 8.96s
#
# 🎯 Trial 958/4000...
#    🔍 Final Train Loss (avg): 0.048052 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 8.89s
#
# 🎯 Trial 959/4000...
#    🔍 Final Train Loss (avg): 0.054264 | Best so far: 0.033822 | Train Acc: 96.48% | Time: 8.97s
#
# 🎯 Trial 960/4000...
#    🔍 Final Train Loss (avg): 0.057051 | Best so far: 0.033822 | Train Acc: 96.48% | Time: 8.94s
#
# 🎯 Trial 961/4000...
#    🔍 Final Train Loss (avg): 0.059140 | Best so far: 0.033822 | Train Acc: 95.77% | Time: 8.83s
#
# 🎯 Trial 962/4000...
#    🔍 Final Train Loss (avg): 0.053456 | Best so far: 0.033822 | Train Acc: 100.00% | Time: 8.79s
#
# 🎯 Trial 963/4000...
#    🔍 Final Train Loss (avg): 0.054949 | Best so far: 0.033822 | Train Acc: 97.18% | Time: 8.95s
#
# 🎯 Trial 964/4000...
#    🔍 Final Train Loss (avg): 0.051516 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 8.98s
#
# 🎯 Trial 965/4000...
#    🔍 Final Train Loss (avg): 0.053713 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 8.88s
#
# 🎯 Trial 966/4000...
#    🔍 Final Train Loss (avg): 0.044596 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 8.98s
#
# 🎯 Trial 967/4000...
#    🔍 Final Train Loss (avg): 0.041475 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 8.78s
#
# 🎯 Trial 968/4000...
#    🔍 Final Train Loss (avg): 0.050251 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 8.85s
#
# 🎯 Trial 969/4000...
#    🔍 Final Train Loss (avg): 0.044846 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 9.03s
#
# 🎯 Trial 970/4000...
#    🔍 Final Train Loss (avg): 0.043457 | Best so far: 0.033822 | Train Acc: 97.18% | Time: 8.89s
#
# 🎯 Trial 971/4000...
#    🔍 Final Train Loss (avg): 0.062981 | Best so far: 0.033822 | Train Acc: 97.18% | Time: 8.81s
#
# 🎯 Trial 972/4000...
#    🔍 Final Train Loss (avg): 0.046862 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 8.76s
#
# 🎯 Trial 973/4000...
#    🔍 Final Train Loss (avg): 0.050508 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 8.82s
#
# 🎯 Trial 974/4000...
#    🔍 Final Train Loss (avg): 0.045859 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 8.70s
#
# 🎯 Trial 975/4000...
#    🔍 Final Train Loss (avg): 0.041598 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 8.77s
#
# 🎯 Trial 976/4000...
#    🔍 Final Train Loss (avg): 0.052280 | Best so far: 0.033822 | Train Acc: 97.18% | Time: 8.69s
#
# 🎯 Trial 977/4000...
#    🔍 Final Train Loss (avg): 0.052653 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 8.75s
#
# 🎯 Trial 978/4000...
#    🔍 Final Train Loss (avg): 0.044714 | Best so far: 0.033822 | Train Acc: 97.18% | Time: 8.71s
#
# 🎯 Trial 979/4000...
#    🔍 Final Train Loss (avg): 0.042452 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 8.73s
#
# 🎯 Trial 980/4000...
#    🔍 Final Train Loss (avg): 0.045999 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 8.70s
#
# 🎯 Trial 981/4000...
#    🔍 Final Train Loss (avg): 0.051991 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 8.69s
#
# 🎯 Trial 982/4000...
#    🔍 Final Train Loss (avg): 0.051773 | Best so far: 0.033822 | Train Acc: 97.18% | Time: 8.69s
#
# 🎯 Trial 983/4000...
#    🔍 Final Train Loss (avg): 0.050981 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 8.73s
#
# 🎯 Trial 984/4000...
#    🔍 Final Train Loss (avg): 0.056085 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 8.70s
#
# 🎯 Trial 985/4000...
#    🔍 Final Train Loss (avg): 0.047723 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 8.66s
#
# 🎯 Trial 986/4000...
#    🔍 Final Train Loss (avg): 0.045367 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 8.79s
#
# 🎯 Trial 987/4000...
#    🔍 Final Train Loss (avg): 0.047419 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 8.75s
#
# 🎯 Trial 988/4000...
#    🔍 Final Train Loss (avg): 0.055924 | Best so far: 0.033822 | Train Acc: 95.77% | Time: 8.73s
#
# 🎯 Trial 989/4000...
#    🔍 Final Train Loss (avg): 0.051957 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 8.71s
#
# 🎯 Trial 990/4000...
#    🔍 Final Train Loss (avg): 0.057744 | Best so far: 0.033822 | Train Acc: 96.48% | Time: 8.81s
#
# 🎯 Trial 991/4000...
#    🔍 Final Train Loss (avg): 0.042439 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 8.71s
#
# 🎯 Trial 992/4000...
#    🔍 Final Train Loss (avg): 0.047154 | Best so far: 0.033822 | Train Acc: 96.48% | Time: 8.88s
#
# 🎯 Trial 993/4000...
#    🔍 Final Train Loss (avg): 0.045760 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 8.75s
#
# 🎯 Trial 994/4000...
#    🔍 Final Train Loss (avg): 0.046201 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 8.78s
#
# 🎯 Trial 995/4000...
#    🔍 Final Train Loss (avg): 0.067487 | Best so far: 0.033822 | Train Acc: 94.37% | Time: 8.80s
#
# 🎯 Trial 996/4000...
#    🔍 Final Train Loss (avg): 0.049557 | Best so far: 0.033822 | Train Acc: 97.18% | Time: 8.87s
#
# 🎯 Trial 997/4000...
#    🔍 Final Train Loss (avg): 0.046019 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 8.91s
#
# 🎯 Trial 998/4000...
#    🔍 Final Train Loss (avg): 0.048063 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 8.89s
#
# 🎯 Trial 999/4000...
#    🔍 Final Train Loss (avg): 0.054284 | Best so far: 0.033822 | Train Acc: 96.48% | Time: 8.84s
#
# 🎯 Trial 1000/4000...
#    🔍 Final Train Loss (avg): 0.045820 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 8.89s
#
# 🎯 Trial 1001/4000...
#    🔍 Final Train Loss (avg): 0.047883 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 8.97s
#
# 🎯 Trial 1002/4000...
#    🔍 Final Train Loss (avg): 0.048070 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 8.93s
#
# 🎯 Trial 1003/4000...
#    🔍 Final Train Loss (avg): 0.046723 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 8.85s
#
# 🎯 Trial 1004/4000...
#    🔍 Final Train Loss (avg): 0.052051 | Best so far: 0.033822 | Train Acc: 96.48% | Time: 8.86s
#
# 🎯 Trial 1005/4000...
#    🔍 Final Train Loss (avg): 0.038205 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 8.79s
#
# 🎯 Trial 1006/4000...
#    🔍 Final Train Loss (avg): 0.045076 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 8.96s
#
# 🎯 Trial 1007/4000...
#    🔍 Final Train Loss (avg): 0.058196 | Best so far: 0.033822 | Train Acc: 97.18% | Time: 8.84s
#
# 🎯 Trial 1008/4000...
#    🔍 Final Train Loss (avg): 0.044180 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 8.93s
#
# 🎯 Trial 1009/4000...
#    🔍 Final Train Loss (avg): 0.047577 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 8.96s
#
# 🎯 Trial 1010/4000...
#    🔍 Final Train Loss (avg): 0.049644 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 8.87s
#
# 🎯 Trial 1011/4000...
#    🔍 Final Train Loss (avg): 0.047179 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 9.15s
#
# 🎯 Trial 1012/4000...
#    🔍 Final Train Loss (avg): 0.047851 | Best so far: 0.033822 | Train Acc: 97.18% | Time: 8.95s
#
# 🎯 Trial 1013/4000...
#    🔍 Final Train Loss (avg): 0.036734 | Best so far: 0.033822 | Train Acc: 100.00% | Time: 8.76s
#
# 🎯 Trial 1014/4000...
#    🔍 Final Train Loss (avg): 0.051587 | Best so far: 0.033822 | Train Acc: 97.18% | Time: 8.75s
#
# 🎯 Trial 1015/4000...
#    🔍 Final Train Loss (avg): 0.039447 | Best so far: 0.033822 | Train Acc: 100.00% | Time: 8.92s
#
# 🎯 Trial 1016/4000...
#    🔍 Final Train Loss (avg): 0.046313 | Best so far: 0.033822 | Train Acc: 100.00% | Time: 8.73s
#
# 🎯 Trial 1017/4000...
#    🔍 Final Train Loss (avg): 0.046771 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 8.71s
#
# 🎯 Trial 1018/4000...
#    🔍 Final Train Loss (avg): 0.050807 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 8.79s
#
# 🎯 Trial 1019/4000...
#    🔍 Final Train Loss (avg): 0.043253 | Best so far: 0.033822 | Train Acc: 97.18% | Time: 8.79s
#
# 🎯 Trial 1020/4000...
#    🔍 Final Train Loss (avg): 0.040570 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 8.62s
#
# 🎯 Trial 1021/4000...
#    🔍 Final Train Loss (avg): 0.056078 | Best so far: 0.033822 | Train Acc: 97.18% | Time: 8.81s
#
# 🎯 Trial 1022/4000...
#    🔍 Final Train Loss (avg): 0.061749 | Best so far: 0.033822 | Train Acc: 95.77% | Time: 8.86s
#
# 🎯 Trial 1023/4000...
#    🔍 Final Train Loss (avg): 0.040120 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 8.91s
#
# 🎯 Trial 1024/4000...
#    🔍 Final Train Loss (avg): 0.052294 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 8.79s
#
# 🎯 Trial 1025/4000...
#    🔍 Final Train Loss (avg): 0.047653 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 8.71s
#
# 🎯 Trial 1026/4000...
#    🔍 Final Train Loss (avg): 0.048022 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 8.73s
#
# 🎯 Trial 1027/4000...
#    🔍 Final Train Loss (avg): 0.052879 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 8.75s
#
# 🎯 Trial 1028/4000...
#    🔍 Final Train Loss (avg): 0.052898 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 8.74s
#
# 🎯 Trial 1029/4000...
#    🔍 Final Train Loss (avg): 0.062837 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 8.73s
#
# 🎯 Trial 1030/4000...
#    🔍 Final Train Loss (avg): 0.049323 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 8.80s
#
# 🎯 Trial 1031/4000...
#    🔍 Final Train Loss (avg): 0.044738 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 9.67s
#
# 🎯 Trial 1032/4000...
#    🔍 Final Train Loss (avg): 0.044097 | Best so far: 0.033822 | Train Acc: 96.48% | Time: 10.30s
#
# 🎯 Trial 1033/4000...
#    🔍 Final Train Loss (avg): 0.049551 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 10.00s
#
# 🎯 Trial 1034/4000...
#    🔍 Final Train Loss (avg): 0.052353 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 10.16s
#
# 🎯 Trial 1035/4000...
#    🔍 Final Train Loss (avg): 0.047658 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 9.68s
#
# 🎯 Trial 1036/4000...
#    🔍 Final Train Loss (avg): 0.045572 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 9.48s
#
# 🎯 Trial 1037/4000...
#    🔍 Final Train Loss (avg): 0.052056 | Best so far: 0.033822 | Train Acc: 100.00% | Time: 9.45s
#
# 🎯 Trial 1038/4000...
#    🔍 Final Train Loss (avg): 0.051736 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 9.49s
#
# 🎯 Trial 1039/4000...
#    🔍 Final Train Loss (avg): 0.052835 | Best so far: 0.033822 | Train Acc: 96.48% | Time: 9.46s
#
# 🎯 Trial 1040/4000...
#    🔍 Final Train Loss (avg): 0.060055 | Best so far: 0.033822 | Train Acc: 96.48% | Time: 9.45s
#
# 🎯 Trial 1041/4000...
#    🔍 Final Train Loss (avg): 0.046275 | Best so far: 0.033822 | Train Acc: 96.48% | Time: 9.44s
#
# 🎯 Trial 1042/4000...
#    🔍 Final Train Loss (avg): 0.055075 | Best so far: 0.033822 | Train Acc: 97.18% | Time: 9.51s
#
# 🎯 Trial 1043/4000...
#    🔍 Final Train Loss (avg): 0.059323 | Best so far: 0.033822 | Train Acc: 96.48% | Time: 9.68s
#
# 🎯 Trial 1044/4000...
#    🔍 Final Train Loss (avg): 0.048668 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 9.59s
#
# 🎯 Trial 1045/4000...
#    🔍 Final Train Loss (avg): 0.056057 | Best so far: 0.033822 | Train Acc: 95.77% | Time: 9.56s
#
# 🎯 Trial 1046/4000...
#    🔍 Final Train Loss (avg): 0.053452 | Best so far: 0.033822 | Train Acc: 97.18% | Time: 9.58s
#
# 🎯 Trial 1047/4000...
#    🔍 Final Train Loss (avg): 0.046353 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 9.52s
#
# 🎯 Trial 1048/4000...
#    🔍 Final Train Loss (avg): 0.048201 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 9.46s
#
# 🎯 Trial 1049/4000...
#    🔍 Final Train Loss (avg): 0.052159 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 9.48s
#
# 🎯 Trial 1050/4000...
#    🔍 Final Train Loss (avg): 0.046262 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 9.43s
#
# 🎯 Trial 1051/4000...
#    🔍 Final Train Loss (avg): 0.042299 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 9.43s
#
# 🎯 Trial 1052/4000...
#    🔍 Final Train Loss (avg): 0.055956 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 9.54s
#
# 🎯 Trial 1053/4000...
#    🔍 Final Train Loss (avg): 0.039301 | Best so far: 0.033822 | Train Acc: 100.00% | Time: 9.45s
#
# 🎯 Trial 1054/4000...
#    🔍 Final Train Loss (avg): 0.054690 | Best so far: 0.033822 | Train Acc: 93.66% | Time: 9.49s
#
# 🎯 Trial 1055/4000...
#    🔍 Final Train Loss (avg): 0.046311 | Best so far: 0.033822 | Train Acc: 96.48% | Time: 9.66s
#
# 🎯 Trial 1056/4000...
#    🔍 Final Train Loss (avg): 0.059324 | Best so far: 0.033822 | Train Acc: 95.07% | Time: 9.51s
#
# 🎯 Trial 1057/4000...
#    🔍 Final Train Loss (avg): 0.046858 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 9.16s
#
# 🎯 Trial 1058/4000...
#    🔍 Final Train Loss (avg): 0.050440 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 8.93s
#
# 🎯 Trial 1059/4000...
#    🔍 Final Train Loss (avg): 0.052232 | Best so far: 0.033822 | Train Acc: 97.18% | Time: 8.92s
#
# 🎯 Trial 1060/4000...
#    🔍 Final Train Loss (avg): 0.047775 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 9.16s
#
# 🎯 Trial 1061/4000...
#    🔍 Final Train Loss (avg): 0.060328 | Best so far: 0.033822 | Train Acc: 97.18% | Time: 8.94s
#
# 🎯 Trial 1062/4000...
#    🔍 Final Train Loss (avg): 0.059371 | Best so far: 0.033822 | Train Acc: 95.77% | Time: 8.94s
#
# 🎯 Trial 1063/4000...
#    🔍 Final Train Loss (avg): 0.047411 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 8.76s
#
# 🎯 Trial 1064/4000...
#    🔍 Final Train Loss (avg): 0.045588 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 8.93s
#
# 🎯 Trial 1065/4000...
#    🔍 Final Train Loss (avg): 0.049318 | Best so far: 0.033822 | Train Acc: 97.18% | Time: 9.24s
#
# 🎯 Trial 1066/4000...
#    🔍 Final Train Loss (avg): 0.053271 | Best so far: 0.033822 | Train Acc: 95.77% | Time: 9.27s
#
# 🎯 Trial 1067/4000...
#    🔍 Final Train Loss (avg): 0.053415 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 8.96s
#
# 🎯 Trial 1068/4000...
#    🔍 Final Train Loss (avg): 0.059556 | Best so far: 0.033822 | Train Acc: 95.77% | Time: 8.94s
#
# 🎯 Trial 1069/4000...
#    🔍 Final Train Loss (avg): 0.044523 | Best so far: 0.033822 | Train Acc: 98.59% | Time: 9.25s
#
# 🎯 Trial 1070/4000...
#    🔍 Final Train Loss (avg): 0.056612 | Best so far: 0.033822 | Train Acc: 95.07% | Time: 8.83s
#
# 🎯 Trial 1071/4000...
#    🔍 Final Train Loss (avg): 0.044325 | Best so far: 0.033822 | Train Acc: 97.89% | Time: 9.19s
#
# 🎯 Trial 1072/4000...
#    🔍 Final Train Loss (avg): 0.058604 | Best so far: 0.033822 | Train Acc: 95.77% | Time: 8.99s
#
# 🎯 Trial 1073/4000...
#    🔍 Final Train Loss (avg): 0.057453 | Best so far: 0.033822 | Train Acc: 97.18% | Time: 9.58s
#
# 🎯 Trial 1074/4000...
#    🔍 Final Train Loss (avg): 0.045164 | Best so far: 0.033822 | Train Acc: 99.30% | Time: 9.52s
#
# 🎯 Trial 1075/4000...
#    🔍 Final Train Loss (avg): 0.053070 | Best so far: 0.033822 | Train Acc: 97.18% | Time: 9.70s
#
# 🎯 Trial 1076/4000...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 91
#      89 for data, target in train_dl:
#      90     optimizer.zero_grad()
# ---> 91     out = model(data)
#      92     loss = cost_fidelity(out, target)
#      93     loss.backward()
#
# File /opt/anaconda3/envs/QML-Qudits/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/QML-Qudits/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# Cell In[3], line 233, in QNN_0_Prod.forward(self, batch)
#     231     G = self.gens_enc[j]
#     232     x = batch_c[:, j].view(-1, 1, 1)
# --> 233     U = torch.matrix_exp(1j * x * G)
#     234     state = torch.bmm(U, state)
#     236 # Variational
#
# KeyboardInterrupt:
