# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import os

# %% [markdown]
# ## 4 PARAMETERS

# %%
files = glob.glob("/Users/ccristiano/Documents/Codigos/QML/MNIST/qutrit/data/TestConvergence_GeneralSUN/train_progress_NUMFEATURES_6_NUM_PARAMS_4_*.csv")
files_sorted = sorted(files, key=lambda x: int(os.path.splitext(os.path.basename(x))[0].split("_")[-1]))

dfs = []
for file in files_sorted:
    df = pd.read_csv(file)
    # opcional: guardar número de trial según el nombre
    trial_num = int(os.path.splitext(os.path.basename(file))[0].split("_")[-1])
    df["FileTrial"] = trial_num
    dfs.append(df)
all_data = pd.concat(dfs, ignore_index=True)

# plt.figure(figsize=(8, 4))
# plt.plot(all_data["Trial"], all_data["BestTrainLoss"], marker='o', label="Loss")
# plt.xlabel("Trial")
# plt.ylabel("Best Train Loss so far")
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# Average every 200 trials
all_data["trial_block"] = all_data["Trial"] // 200
loss_means = all_data.groupby("trial_block")["BestTrainLoss"].mean().reset_index()
plt.figure(figsize=(8,4))
plt.plot(loss_means["trial_block"], loss_means["BestTrainLoss"], marker='o', color='indianred')
plt.xlabel("Trial Block (each = 200 trials)", fontsize=17)
plt.ylabel("Average Best Train Loss", fontsize=17)
plt.title("Features = 5 | Params = 4", fontsize=17)
plt.grid(linestyle='dotted', color='lightgrey')
plt.show()

BestLoss_4params = min(all_data["BestTrainLoss"])
BestTrial_4params = all_data["Trial"][all_data["BestTrainLoss"] == BestLoss_4params].iloc[0]
print("Best Loss = ", str(BestLoss_4params))
print("Best Trial = ", str(BestTrial_4params))
# Out:
# Best Loss =  0.0153525751084089
# Best Trial =  3311

# %% [markdown]
# ## 5 PARAMETERS

# %%
files = glob.glob("/Users/ccristiano/Documents/Codigos/QML/MNIST/qutrit/data/TestConvergence_GeneralSUN/train_progress_NUMFEATURES_6_NUM_PARAMS_5_*.csv")
files_sorted = sorted(files, key=lambda x: int(os.path.splitext(os.path.basename(x))[0].split("_")[-1]))

dfs = []
for file in files_sorted:
    df = pd.read_csv(file)
    # opcional: guardar número de trial según el nombre
    trial_num = int(os.path.splitext(os.path.basename(file))[0].split("_")[-1])
    df["FileTrial"] = trial_num
    dfs.append(df)
all_data = pd.concat(dfs, ignore_index=True)

# plt.figure(figsize=(8, 4))
# plt.plot(all_data["Trial"], all_data["BestTrainLoss"], marker='o', label="Loss")
# plt.xlabel("Trial")
# plt.ylabel("Best Train Loss so far")
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# Average every 200 trials
all_data["trial_block"] = all_data["Trial"] // 200
loss_means = all_data.groupby("trial_block")["BestTrainLoss"].mean().reset_index()
plt.figure(figsize=(8,4))
plt.plot(loss_means["trial_block"], loss_means["BestTrainLoss"], marker='o', color='indianred')
plt.xlabel("Trial Block (each = 200 trials)", fontsize=17)
plt.title("Features = 5 | Params = 5", fontsize=17)
plt.ylabel("Average Best Train Loss", fontsize=17)
plt.grid(linestyle='dotted', color='lightgrey')
plt.show()

BestLoss_5params = min(all_data["BestTrainLoss"])
BestTrial_5params = all_data["Trial"][all_data["BestTrainLoss"] == BestLoss_5params].iloc[0]
print("Best Loss = ", str(BestLoss_5params))
print("Best Trial = ", str(BestTrial_5params))
# Out:
# Best Loss =  0.0119225047528743
# Best Trial =  2555

# %% [markdown]
# ## 6 PARAMETERS

# %%
files = glob.glob("/Users/ccristiano/Documents/Codigos/QML/MNIST/qutrit/data/TestConvergence_GeneralSUN/train_progress_NUMFEATURES_6_NUM_PARAMS_6_*.csv")
files_sorted = sorted(files, key=lambda x: int(os.path.splitext(os.path.basename(x))[0].split("_")[-1]))

dfs = []
for file in files_sorted:
    df = pd.read_csv(file)
    # opcional: guardar número de trial según el nombre
    trial_num = int(os.path.splitext(os.path.basename(file))[0].split("_")[-1])
    df["FileTrial"] = trial_num
    dfs.append(df)
all_data = pd.concat(dfs, ignore_index=True)

# plt.figure(figsize=(8, 4))
# plt.plot(all_data["Trial"], all_data["BestTrainLoss"], marker='o', label="Loss")
# plt.xlabel("Trial")
# plt.ylabel("Best Train Loss so far")
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# Average every 200 trials
all_data["trial_block"] = all_data["Trial"] // 200
loss_means = all_data.groupby("trial_block")["BestTrainLoss"].mean().reset_index()
plt.figure(figsize=(8,4))
plt.plot(loss_means["trial_block"], loss_means["BestTrainLoss"], marker='o', color='indianred')
plt.xlabel("Trial Block (each = 200 trials)", fontsize=17)
plt.ylabel("Average Best Train Loss", fontsize=17)
plt.title("Features = 5 | Params = 6", fontsize=17)
plt.grid(linestyle='dotted', color='lightgrey')
plt.show()

BestLoss_6params = min(all_data["BestTrainLoss"])
BestTrial_6params = all_data["Trial"][all_data["BestTrainLoss"] == BestLoss_6params].iloc[0]
print("Best Loss = ", str(BestLoss_6params))
print("Best Trial = ", str(BestTrial_6params))
# Out:
# Best Loss =  0.0116104744374752
# Best Trial =  3050

# %% [markdown]
# ## 7 PARAMETERS

# %%
files = glob.glob("/Users/ccristiano/Documents/Codigos/QML/MNIST/qutrit/data/TestConvergence_GeneralSUN/train_progress_NUMFEATURES_6_NUM_PARAMS_7_*.csv")
files_sorted = sorted(files, key=lambda x: int(os.path.splitext(os.path.basename(x))[0].split("_")[-1]))

dfs = []
for file in files_sorted:
    df = pd.read_csv(file)
    # opcional: guardar número de trial según el nombre
    trial_num = int(os.path.splitext(os.path.basename(file))[0].split("_")[-1])
    df["FileTrial"] = trial_num
    dfs.append(df)
all_data = pd.concat(dfs, ignore_index=True)

# plt.figure(figsize=(8, 4))
# plt.plot(all_data["Trial"], all_data["BestTrainLoss"], marker='o', label="Loss")
# plt.xlabel("Trial")
# plt.ylabel("Best Train Loss so far")
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# Average every 200 trials
all_data["trial_block"] = all_data["Trial"] // 200
loss_means = all_data.groupby("trial_block")["BestTrainLoss"].mean().reset_index()
plt.figure(figsize=(8,4))
plt.plot(loss_means["trial_block"], loss_means["BestTrainLoss"], marker='o', color='indianred')
plt.xlabel("Trial Block (each = 200 trials)", fontsize=17)
plt.ylabel("Average Best Train Loss", fontsize=17)
plt.title("Features = 5 | Params = 7", fontsize=17)
plt.grid(linestyle='dotted', color='lightgrey')
plt.show()

BestLoss_7params = min(all_data["BestTrainLoss"])
BestTrial_7params = all_data["Trial"][all_data["BestTrainLoss"] == BestLoss_7params].iloc[0]
print("Best Loss = ", str(BestLoss_7params))
print("Best Trial = ", str(BestTrial_7params))
# Out:
# Best Loss =  0.0078123649582266
# Best Trial =  900

# %% [markdown]
# ## 8 PARAMETERS

# %%
files = glob.glob("/Users/ccristiano/Documents/Codigos/QML/MNIST/qutrit/data/TestConvergence/train_progress_NUMFEATURES_6_NUM_PARAMS_8_*.csv")
files_sorted = sorted(files, key=lambda x: int(os.path.splitext(os.path.basename(x))[0].split("_")[-1]))

dfs = []
for file in files_sorted:
    df = pd.read_csv(file)
    # opcional: guardar número de trial según el nombre
    trial_num = int(os.path.splitext(os.path.basename(file))[0].split("_")[-1])
    df["FileTrial"] = trial_num
    dfs.append(df)
all_data = pd.concat(dfs, ignore_index=True)

# plt.figure(figsize=(8, 4))
# plt.plot(all_data["Trial"], all_data["BestTrainLoss"], marker='o', label="Loss")
# plt.xlabel("Trial")
# plt.ylabel("Best Train Loss so far")
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# Average every 200 trials
all_data["trial_block"] = all_data["Trial"] // 200
loss_means = all_data.groupby("trial_block")["BestTrainLoss"].mean().reset_index()
plt.figure(figsize=(8,4))
plt.plot(loss_means["trial_block"], loss_means["BestTrainLoss"], marker='o', color='indianred')
plt.xlabel("Trial Block (each = 200 trials)", fontsize=17)
plt.ylabel("Average Best Train Loss", fontsize=17)
plt.title("Features = 8 | Params = 8", fontsize=17)
plt.grid(linestyle='dotted', color='lightgrey')
plt.show()

BestLoss_8params = min(all_data["BestTrainLoss"])
BestTrial_8params = all_data["Trial"][all_data["BestTrainLoss"] == BestLoss_8params].iloc[0]
print("Best Loss = ", str(BestLoss_8params))
print("Best Trial = ", str(BestTrial_8params))
# Out:
# Best Loss =  0.0048632393591105
# Best Trial =  1196

# %% [markdown]
# ## Comparison

# %%
Best_Loss = [BestLoss_4params,
            BestLoss_5params,
            BestLoss_6params,
            BestLoss_7params,
            BestLoss_8params]

Best_Trial = [BestTrial_4params,
             BestTrial_5params,
             BestTrial_6params,
             BestTrial_7params,
              BestTrial_8params]

n_params   = np.arange(4,9)

plt.figure(figsize=(8,4))
plt.plot(n_params, np.array(Best_Loss), marker='o', color='tab:purple')
plt.xlabel("# params", fontsize=17)
plt.ylabel("Best Loss", fontsize=17)
plt.xticks(n_params)
plt.grid(linestyle='dotted', color='lightgrey')
plt.show()

plt.figure(figsize=(8,4))
plt.plot(n_params, np.array(Best_Trial), marker='o', color='mediumseagreen')
plt.xlabel("# params", fontsize=17)
plt.ylabel("Best Trial", fontsize=17)
plt.xticks(n_params)
plt.grid(linestyle='dotted', color='lightgrey')
plt.show()

# %%
df_summary = pd.DataFrame({
    "n_params": n_params,
    "Best_Loss": Best_Loss,
    "Best_Trial": Best_Trial
})

df_summary.to_csv("/Users/ccristiano/Documents/Codigos/QML/MNIST/qutrit/data/TestConvergence/data_NUM_FEATURES_6.csv", index=False)
